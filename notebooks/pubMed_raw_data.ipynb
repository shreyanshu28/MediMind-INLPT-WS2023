# %%
'''
pip install biopython
pip install python-dotenv
pip install biopython python-dotenv
'''
# Out:
# '\npip install biopython\npip install python-dotenv\npip install biopython python-dotenv\n'

# %%
from Bio import Entrez
import time
import os
from dotenv import load_dotenv
import math
import calendar

# %%
# define the project directory
project_dir = os.path.dirname(os.getcwd())

# define data directory
data_dir = os.path.join(project_dir, 'data','PubMed_Format')


# Load environment variables (Note write the EMAIL & API_keys in Config/.env file)
dotenv_path = os.path.join(project_dir, 'config', '.env')
load_dotenv(dotenv_path=dotenv_path)

# %%
def search_and_download_abstracts(query, email, api_key, start_date, end_date, output_file):
    Entrez.email = email       # Set The email
    Entrez.api_key = api_key  # Set the API key
        
    search_handle = Entrez.esearch(db="pubmed",
                                   term=query,
                                   datetype="pdat",
                                   mindate= start_date,
                                   maxdate= end_date,
                                   usehistory="y")
    search_results = Entrez.read(search_handle)
    search_handle.close()

    count = int(search_results["Count"])
    
    # to avoid the API limit of 10000 records
    if count > 10000:
        return -1
    
    batch_size = 1000
    
    print(f"Found {count} results. Downloading abstracts... for year {start_date[:7]} -> {end_date[:7]}")

    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    # Check if file exists to determine mode ('a' for append, 'w' for write)
    file_mode = 'a' if os.path.isfile(output_file) else 'w'
    
    with open(output_file, file_mode) as out_file:
        if file_mode == 'a':
            out_file.write("\n")  # Ensure there's a newline before appending if file exists
        for start in range(0, count, batch_size):
            end = min(count, start + batch_size)
            print(f"Downloading record {start + 1} to {end} of {count}")
            fetch_handle = Entrez.efetch(db="pubmed",
                                         rettype="medline",
                                         retmode="text",
                                         retstart=start,
                                         retmax=batch_size,
                                         webenv=search_results["WebEnv"],
                                         query_key=search_results["QueryKey"])
            data = fetch_handle.read()
            fetch_handle.close()
            out_file.write(data)
            time.sleep(1)  # Respect PubMed's servers by sleeping 1 second between requests
    
    return count

# %%
total_number_of_records = 0
current_year_count = 0
current_month_count = 0

query = 'intelligence[Title/Abstract]'
email = os.environ["EMAIL"]
api_key = os.environ["API_KEY"]

for year in range(2013, 2025):
    output_file = os.path.join(project_dir, 'data', f'raw_pubmed_intelligence_abstracts_{year}.txt')
    current_year_count = search_and_download_abstracts(query, email, api_key,
                                                       start_date=f"{year}-01-01",
                                                       end_date=f"{year}-12-31",
                                                       output_file=output_file)
    
    # If the return is -1, it means the number of records is greater than 10,000
    if current_year_count == -1:
        for month in range(1, 13, 1):  # Start at 1, end before 13, increment by 1
            # Determine the last day of the month
            month_end_day = calendar.monthrange(year, month)[1]
            
            # Perform the search and download operation
            current_month_count = search_and_download_abstracts(query, email, api_key,
                                                                start_date=f"{year}-{month:02d}-01",
                                                                end_date=f"{year}-{month:02d}-{month_end_day}",
                                                                output_file=output_file)
            total_number_of_records += current_month_count
            
    else:
        total_number_of_records += current_month_count

# The total number of downloaded records : 63333 records
print(f"total number of downloaded records {total_number_of_records}")
# Out:
# Found 1660 results. Downloading abstracts... for year 2013-01 -> 2013-12
# Downloading record 1 to 1000 of 1660
# Downloading record 1001 to 1660 of 1660
# Found 1798 results. Downloading abstracts... for year 2014-01 -> 2014-12
# Downloading record 1 to 1000 of 1798
# Downloading record 1001 to 1798 of 1798
# Found 1974 results. Downloading abstracts... for year 2015-01 -> 2015-12
# Downloading record 1 to 1000 of 1974
# Downloading record 1001 to 1974 of 1974
# Found 2011 results. Downloading abstracts... for year 2016-01 -> 2016-12
# Downloading record 1 to 1000 of 2011
# Downloading record 1001 to 2000 of 2011
# Downloading record 2001 to 2011 of 2011
# Found 2359 results. Downloading abstracts... for year 2017-01 -> 2017-12
# Downloading record 1 to 1000 of 2359
# Downloading record 1001 to 2000 of 2359
# Downloading record 2001 to 2359 of 2359
# Found 3341 results. Downloading abstracts... for year 2018-01 -> 2018-12
# Downloading record 1 to 1000 of 3341
# Downloading record 1001 to 2000 of 3341
# Downloading record 2001 to 3000 of 3341
# Downloading record 3001 to 3341 of 3341
# Found 4951 results. Downloading abstracts... for year 2019-01 -> 2019-12
# Downloading record 1 to 1000 of 4951
# Downloading record 1001 to 2000 of 4951
# Downloading record 2001 to 3000 of 4951
# Downloading record 3001 to 4000 of 4951
# Downloading record 4001 to 4951 of 4951
# Found 7875 results. Downloading abstracts... for year 2020-01 -> 2020-12
# Downloading record 1 to 1000 of 7875
# Downloading record 1001 to 2000 of 7875
# Downloading record 2001 to 3000 of 7875
# Downloading record 3001 to 4000 of 7875
# Downloading record 4001 to 5000 of 7875
# Downloading record 5001 to 6000 of 7875
# Downloading record 6001 to 7000 of 7875
# Downloading record 7001 to 7875 of 7875
# Found 2837 results. Downloading abstracts... for year 2021-01 -> 2021-01
# Downloading record 1 to 1000 of 2837
# Downloading record 1001 to 2000 of 2837
# Downloading record 2001 to 2837 of 2837
# Found 976 results. Downloading abstracts... for year 2021-02 -> 2021-02
# Downloading record 1 to 976 of 976
# Found 1053 results. Downloading abstracts... for year 2021-03 -> 2021-03
# Downloading record 1 to 1000 of 1053
# Downloading record 1001 to 1053 of 1053
# Found 980 results. Downloading abstracts... for year 2021-04 -> 2021-04
# Downloading record 1 to 980 of 980
# Found 1085 results. Downloading abstracts... for year 2021-05 -> 2021-05
# Downloading record 1 to 1000 of 1085
# Downloading record 1001 to 1085 of 1085
# Found 1098 results. Downloading abstracts... for year 2021-06 -> 2021-06
# Downloading record 1 to 1000 of 1098
# Downloading record 1001 to 1098 of 1098
# Found 1190 results. Downloading abstracts... for year 2021-07 -> 2021-07
# Downloading record 1 to 1000 of 1190
# Downloading record 1001 to 1190 of 1190
# Found 1074 results. Downloading abstracts... for year 2021-08 -> 2021-08
# Downloading record 1 to 1000 of 1074
# Downloading record 1001 to 1074 of 1074
# Found 1214 results. Downloading abstracts... for year 2021-09 -> 2021-09
# Downloading record 1 to 1000 of 1214
# Downloading record 1001 to 1214 of 1214
# Found 1200 results. Downloading abstracts... for year 2021-10 -> 2021-10
# Downloading record 1 to 1000 of 1200
# Downloading record 1001 to 1200 of 1200
# Found 1270 results. Downloading abstracts... for year 2021-11 -> 2021-11
# Downloading record 1 to 1000 of 1270
# Downloading record 1001 to 1270 of 1270
# Found 1244 results. Downloading abstracts... for year 2021-12 -> 2021-12
# Downloading record 1 to 1000 of 1244
# Downloading record 1001 to 1244 of 1244
# Found 4618 results. Downloading abstracts... for year 2022-01 -> 2022-01
# Downloading record 1 to 1000 of 4618
# Downloading record 1001 to 2000 of 4618
# Downloading record 2001 to 3000 of 4618
# Downloading record 3001 to 4000 of 4618
# Downloading record 4001 to 4618 of 4618
# Found 1205 results. Downloading abstracts... for year 2022-02 -> 2022-02
# Downloading record 1 to 1000 of 1205
# Downloading record 1001 to 1205 of 1205
# Found 1479 results. Downloading abstracts... for year 2022-03 -> 2022-03
# Downloading record 1 to 1000 of 1479
# Downloading record 1001 to 1479 of 1479
# Found 1315 results. Downloading abstracts... for year 2022-04 -> 2022-04
# Downloading record 1 to 1000 of 1315
# Downloading record 1001 to 1315 of 1315
# Found 1457 results. Downloading abstracts... for year 2022-05 -> 2022-05
# Downloading record 1 to 1000 of 1457
# Downloading record 1001 to 1457 of 1457
# Found 1522 results. Downloading abstracts... for year 2022-06 -> 2022-06
# Downloading record 1 to 1000 of 1522
# Downloading record 1001 to 1522 of 1522
# Found 1420 results. Downloading abstracts... for year 2022-07 -> 2022-07
# Downloading record 1 to 1000 of 1420
# Downloading record 1001 to 1420 of 1420
# Found 1487 results. Downloading abstracts... for year 2022-08 -> 2022-08
# Downloading record 1 to 1000 of 1487
# Downloading record 1001 to 1487 of 1487
# Found 1616 results. Downloading abstracts... for year 2022-09 -> 2022-09
# Downloading record 1 to 1000 of 1616
# Downloading record 1001 to 1616 of 1616
# Found 1504 results. Downloading abstracts... for year 2022-10 -> 2022-10
# Downloading record 1 to 1000 of 1504
# Downloading record 1001 to 1504 of 1504
# Found 1534 results. Downloading abstracts... for year 2022-11 -> 2022-11
# Downloading record 1 to 1000 of 1534
# Downloading record 1001 to 1534 of 1534
# Found 1591 results. Downloading abstracts... for year 2022-12 -> 2022-12
# Downloading record 1 to 1000 of 1591
# Downloading record 1001 to 1591 of 1591
# Found 4268 results. Downloading abstracts... for year 2023-01 -> 2023-01
# Downloading record 1 to 1000 of 4268
# Downloading record 1001 to 2000 of 4268
# Downloading record 2001 to 3000 of 4268
# Downloading record 3001 to 4000 of 4268
# Downloading record 4001 to 4268 of 4268
# Found 1584 results. Downloading abstracts... for year 2023-02 -> 2023-02
# Downloading record 1 to 1000 of 1584
# Downloading record 1001 to 1584 of 1584
# Found 1716 results. Downloading abstracts... for year 2023-03 -> 2023-03
# Downloading record 1 to 1000 of 1716
# Downloading record 1001 to 1716 of 1716
# Found 1641 results. Downloading abstracts... for year 2023-04 -> 2023-04
# Downloading record 1 to 1000 of 1641
# Downloading record 1001 to 1641 of 1641
# Found 1776 results. Downloading abstracts... for year 2023-05 -> 2023-05
# Downloading record 1 to 1000 of 1776
# Downloading record 1001 to 1776 of 1776
# Found 1906 results. Downloading abstracts... for year 2023-06 -> 2023-06
# Downloading record 1 to 1000 of 1906
# Downloading record 1001 to 1906 of 1906
# Found 1961 results. Downloading abstracts... for year 2023-07 -> 2023-07
# Downloading record 1 to 1000 of 1961
# Downloading record 1001 to 1961 of 1961
# Found 1955 results. Downloading abstracts... for year 2023-08 -> 2023-08
# Downloading record 1 to 1000 of 1955
# Downloading record 1001 to 1955 of 1955
# Found 2082 results. Downloading abstracts... for year 2023-09 -> 2023-09
# Downloading record 1 to 1000 of 2082
# Downloading record 1001 to 2000 of 2082
# Downloading record 2001 to 2082 of 2082
# Found 2140 results. Downloading abstracts... for year 2023-10 -> 2023-10
# Downloading record 1 to 1000 of 2140
# Downloading record 1001 to 2000 of 2140
# Downloading record 2001 to 2140 of 2140
# Found 2159 results. Downloading abstracts... for year 2023-11 -> 2023-11
# Downloading record 1 to 1000 of 2159
# Downloading record 1001 to 2000 of 2159
# Downloading record 2001 to 2159 of 2159
# Found 2088 results. Downloading abstracts... for year 2023-12 -> 2023-12
# Downloading record 1 to 1000 of 2088
# Downloading record 1001 to 2000 of 2088
# Downloading record 2001 to 2088 of 2088
# Found 4240 results. Downloading abstracts... for year 2024-01 -> 2024-12
# Downloading record 1 to 1000 of 4240
# Downloading record 1001 to 2000 of 4240
# Downloading record 2001 to 3000 of 4240
# Downloading record 3001 to 4000 of 4240
# Downloading record 4001 to 4240 of 4240
# total number of downloaded records 63333 records
