# %% [markdown]
# **Heidelberg University**
#
# **Data Science  Group**
#
# Prof. Dr. Michael Gertz
#
# Ashish Chouhan, Satya Almasian, John Ziegler, Jayson Salazar, Nicolas Reuter
#
# October 30, 2023
#
# Natural Language Processing with Transformers
#
# Winter Semster 2023/2024
# ***

# %% [markdown]
# # **Assignment 1: “Word Embeddings and Probabilistic Language Models”**
# **Due**: Monday, November 13, 2pm, via [Moodle](https://moodle.uni-heidelberg.de/course/view.php?id=19251)

# %% [markdown]
# ### **Submission Guidelines**
#
# - Solutions need to be uploaded as a **single** Jupyter notebook. You will find several pre-filled code segments in the notebook, your task is to fill in the missing cells.
# - For the written solution, use LaTeX in markdown inside the same notebook. Do **not** hand in a separate file for it.
# - Download the .zip file containing the dataset but do **not** upload it with your solution.
# - It is sufficient if one person per group uploads the solution to Moodle, but make sure that the complete names of all team members are given in the notebook.
#
# ***

# %% [markdown]
# ## **Task 1: F.R.I.E.N.D.S and  Word2Vec (Grade (2 + 2 + 4) = 8)**

# %% [markdown]
# [Friends](https://en.wikipedia.org/wiki/Friends) is an American television sitcom, created by David Crane and Marta Kauffman. In this assignment we will use the transcripts from the show to train a Word2Vec model using the [Gensim](https://radimrehurek.com/gensim/) library.

# %% [markdown]
# ### Subtask 1: Pre-processing
# We start by loading and cleaning the data. Download the dataset for this assignment and load the `friends_quotes.csv` using pandas. The dataset is from Kaggle (https://www.kaggle.com/ryanstonebraker/friends-transcript) and is created for building a classifier that  determines which friend from the Friend's TV Show would be most likely to say a quote. The column `quote` contains a line from the movie and the `author` is the one who said it. Since these are the only two columns we need, we remove the rest and only keep these two columns.

# %%
import re
import pandas as pd
from collections import defaultdict
import spacy
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
dataset_path = 'friends_quotes.csv'
# Load the dataset into a pandas DataFrame
df = pd.read_csv(dataset_path)
### filter out columns ###
# Select only the 'quote' and 'author' columns
df = df[['quote', 'author']]
# Drop any rows with missing values (if any)
df.dropna(inplace=True)

# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Display the first few rows of the cleaned DataFrame
#print(df.head())
df.head(10)
# Out:
#                                                quote    author
# 0  There's nothing to tell! He's just some guy I ...    Monica
# 1  C'mon, you're going out with the guy! There's ...      Joey
# 2  All right Joey, be nice. So does he have a hum...  Chandler
# 3                           Wait, does he eat chalk?    Phoebe
# 4  Just, 'cause, I don't want her to go through w...    Phoebe
# 5  Okay, everybody relax. This is not even a date...    Monica
# 6                          Sounds like a date to me.  Chandler
# 7  Alright, so I'm back in high school, I'm stand...  Chandler
# 8                          Oh, yeah. Had that dream.       All
# 9  Then I look down, and I realize there's a phon...  Chandler

# %% [markdown]
# Fortunately, there is no missing data, so we do not need to worry about that.

# %%
df.isnull().sum() # check for missing data
# Out:
# quote     0
# author    0
# dtype: int64

# %% [markdown]
# Use SpaCy to preprocess the text. For this, perform the following steps:
# - lowercase the words
# - remove the stopwords and single characters
# - use regex to remove non-alphabetic characters (anything that is not a number or alphabet including punctuations), in other words only keep "a" to "z" and digits.
# - remove lines that have less than 4 words, since they cannot contribute much to the training process.
#
# Please do not add any additional steps on your own or additional cleaning as we want to achieve comparable results.

# %%
nlp = spacy.load("en_core_web_sm", disable=["tagger", "parser","ner"])
stopwords = spacy.lang.en.stop_words.STOP_WORDS
#df["quote"] = # lowercase and remove non-alphabetic characters
#quotes =[] # to save all the lines

# Function to preprocess and clean text
def preprocess_text(text):
    # Apply SpaCy processing to the text
    doc = nlp(text)
    
    # Tokenize the text, lowercase, and remove stopwords, single characters
    tokens = [token.text.lower() for token in doc if token.text.lower() not in stopwords and len(token.text) > 1]

    # Use regex to remove non-alphabetic characters
    clean_tokens = [re.sub(r'[^a-z0-9]', '', token) for token in tokens]

    # Remove lines with less than 4 words
    if len(clean_tokens) >= 4:
        return ' '.join(clean_tokens)
    return None

# Apply preprocessing to each quote and filter out lines with less than 4 words
df["quote"] = df["quote"].apply(preprocess_text)

# Filter out rows with None (lines with less than 4 words)
df = df.dropna()
quotes = df["quote"].tolist()
### Your Code ###
for quote in quotes:
    print(quote)
# Out:
# C:\Users\ozgeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# cm going guy got ta wrong
# right joey nice hump hump hairpiece
# cause want went carl oh
# okay everybody relax date people going dinner and having sex
# alright high school standing middle cafeteria realize totally naked
# look realize phone
# sudden phone starts ring know everybody starts looking
# finally figure better answer turns mother weird because calls
# guy says hello wanna kill
# feel like reached throat grabbed small intestine pulled mouth tied neck
# explaining carol moved stuff today
# ooh oh starts pluck air ross
# stop cleansing aura leave aura okay
# fine alright hope happy
# okay fixating know know
# wish lesbian  stare loud
# told mom dad night pretty
# oh hysterical phone got woman sobbing 300 am grandchildren grandchildren wrong number
# alright ross look feeling lot pain right angry hurting tell answer
# strip joint cm single hormones
# want single okay  just wanna married
# want million dollars extends hand hopefully
# oh god monica hi thank god went building guy big hammer said
# pointing rachel de caff okay everybody rachel lincoln high survivor rachel everybody chandler phoebe joey and remember brother ross
# wanna tell waiting wet bridesmaids
# oh god  started half hour wedding room keeping presents looking gravy boat gorgeous lamauge gravy boat sudden waitress brought coffeesweet lo realized turned gravy boat barry got freaked hit barry looks like mr potato head yknow mean knew looked familiar  started wondering monica know know kinda drifted apart person knew lived city
# ooh kinda hoping issue  scene monica apartment watching spanish soap tv trying figure going
# guessing bought big pipe organ happy
# imitating characters tuna egg salad decide
# deep voice christine having
# phone daddy  marry sorry love matters
# let hair head fall
# tv ooh wearing pants
# push stairs push stairs push stairs
# cm daddy listen like like life told shoe shoe shoe shoe today stopped said wanna shoe wanna a purse yknow a hat saying want buy hat saying ha metaphor daddy
# look daddy life maybe stay monica
# guess established staying monica
# maybe decision maybe need money wait wait said maybe
# breathe breathe  try think nice calm things
# sings raindrops roses rabbits kittens rachel monica turn look bluebells sleighbells and mittens  la la la la  noodles string
# grins walks kitchen says chandler joey helped
# okay look probably best yknow independence taking control life hat thing
# comforting hey need come joey chandler live hall away lot
# joey stop hitting wedding day
# oh god 630 buzz
# paul wine guy paul
# maybe joey wait real date tonight paul wine guy
# ooh dear diary moment
# rach wait cancel
# ross okay mean want stay
# choked voice good
# normal voice paul wine guy
# mean sell drink complain lot chandler know
# hi come paul  lined door  everybody everybody paul
# hey paul hi wine guy hey
# okay umm umm  ill right got ta ah ah
# change okay sit shows paul seconds
# ooh pulled eyelashes good
# little tip likes rub neck spot starts little red
# yelling bedroom shut joey
# rachel uh  tonight
# kinda supposed headed aruba honeymoon
# right getting honeymoon god  aruba time year  talk your thinks big lizards  feel like tonight joey chandler coming help new furniture
# actually thanks think gon na hang tonight kinda long day
# hey pheebs wanna help
# singing love sweet summer showers love wondrous work art love oh love love  like giant pigeon  crapping heart la la la la la guy gives change guy thank sings la la la la  ohhh
# squatting reading instructions supposed attach brackety thing things bunch little worm guys brackety thing whim guys whatsoever and feel legs
# clutching beer sniffing carol favorite beer drank known
# hey hey hey hey gon na start stuff outta
# ross let ask question got furniture stereo good tv
# know know idiot guess caught started going dentist times week mean clean teeth
# brother going right mess
# try accidentally breaking valuable her
# laughing way i went watch
# actually broke watch wow worst thing shredded boyfriend favorite bath towel
# right scene monica apartment rachel talking phone pacing
# barry sorry  sorry  know probably think said day making love socks  ju stops talking dials phone hi machine cut   look look know girl going incredibly lucky mrs barry finkel idea right chance  maching cuts redials
# stop chandler hits working hammer collapses
# look ross got ta understand relationship lasted longer mento love woman years years closeness sharing end ripped heart think point
# know scariest woman everybody yknow mean woman unfortunately case woman
# talking woman like saying flavor ice cream lemme tell ross lots flavors rocky road cookie dough bing cherry vanilla em jimmies nuts whipped cream best thing happened got married like welcome world grab spoon
# honestly know hungry horny
# stay freezerscene restaurant monica paul eating
#  wanna spell noodles
# fifth date kinda revelation
# oh gon na fifth date
# yeah  yeah think what gon na
# ev  left um able uh perform monica takes sip drink  sexually
# spitting drink shock oh god oh god sorry  sorry
# know spit probably need right um  long
# wow im im im glad smashed watch
# think um  want fifth date
# pause  yeah yeah
# gathered today join joanne louise cunningham charles chachi chachi chachi arcola bound holy matrimony
# oh   joanne loved chachi difference
# scornful grab spoon know long grabbed spoon words billy hero mean
# great story uh got ta got date andrea  angela  andrea  oh man looks chandler
# angela screamer andrea cats
# right thanks june outta exits
# yknow thing to ask woman  gon na ask gazes window
# amazing mean coffee entire life
# listen roll feel like got ta like western omelet  joey chandler taste coffee grimace pour plant pot actually hungry
# entering oh good lenny squigy
# entering monica room morning
# telling night like umm birthdays graduations plus barn raising scene witness
# yeah kiss thank exits
# real date hell real date
# right kids got ta work input numbers  difference
# yeah jobs buy stuff
# oh wait wait happened catch reruns production pinocchio little theater park
# look gippetto real live boy
# abuse walks door opens leave
# right sorry burst song dances door wooden boy little wooden boy
# know dead man oh chandler starts chandler
# today sleep okay talk barry stop smiling
# look like slept hanger mouth
# know  remember tony demarco
# want wedding dress hardly
# think getting little ahead selves okay okay going work think day gon na work
# oh look wish luck
# gon na thinks job things
# hey frannie welcome florida
# oh hate pushing aunt roz parrot jungle having sex
# paul wine guy oh yeah know paul
# mean know paul like know paul
# kidding credit paul yknow snap turtle years
# sitting arm couchof course line
# assume looking answer sophisticated bed
# hate men hate men
# oh hate want universe
# like sort beacon dogs men severe emotional problems hear
# right cmere gimme feet starts massaging
# bursts laughing believe know line
# kidding trained laughed interviews today
# found john david boots sale percent
# new need job need parents got great boots boots
# um   father
# oh god come guys necessary mean stop charging anytime want
# cm live parents life
# welcome remember came city fourteen mom killed step dad prison got know anybody ended living albino guy like cleaning windshields outside port authority killed found aromatherapy believe know exactly feel
# ready ready hey rach ready jump airplane parachute come
# come coffee chandler slowly tries hide dead plant morning joey poured coffee
# cm cut cut cut cut
# cut cut cut cut cut cut cut  cuts cheer
# yknow think leave kinda like symbolic gesture
# cut cut cut cut cut cut cut
# rachel cutting cards yknow listen closely hear thousand retailers scream
# welcome real world sucks gon na love
# ross gon na crash couch
# hey mon look found floor monica smiles
# paul watch found oh boy alright goodnight everybody
# mmm reach cookie oh no
# okay split know probably know high school um major crush
# oh  figured thought monica geeky older brother
# oh listen think try let intense vulnerability kind factor here think okay asked maybe
# okay  okay maybe
# grabbed spoon ross exits monica idea means
# sings believe hearing
# said nice butt great butt
# oh know great butt came bit ya
# walks pot coffee anybody like coffee
# yeah yeah cup coffee
# kids new dream  las vegas rachel sits hear chandler dream
# rachel ahh miss coffee
# ugh customer leaving excuse guy hands coffee pot ahead thank gang sorry okay las vegas
# okay las vegas  liza minelli
# guys understand kissing important
# yeah right  yserious
# yeah think kissing pretty like opening act yknow mean like stand comedian sit pink floyd comes
# yeah like comedian  bought ticket
# problem concert matter great girls looking comedian yknow mean car fighting traffic  basically trying stay awake
# yeah word advice bring comedian time gon na find sitting home listening album
# pause  talking sex
# good good that mm little angry
# banging women head club sits home trying mastodon smell carpet
# marsha cave people okay issues like gee glacier getting kinda close
# speaking issues ex wife
# okay okay yes waves uh catch ice age
# look great uh  hate
# ah  stands erect  new uh
#  know um  family
# marty totally paranoid oh uh
# oh think episode company kind misunderstanding
#  seen turns tv
# yeah sorry swallowing slowed
# oh uh wrote note realised need balled  sees monica glaring  wish dead
# fluffed pillow  monica know fluffed that monica glares but fine
# look sorry guys wanna ammunition
# yes know cruel parent flatness child pillow
# monica hi um monica scaring mean like like chaotic twirly good way
# yeah calm ross getting chaotic twirly time come
# far parents concerned ross wrong ysee prince apparently big ceremony born
# looking window ew ew ew ew ew ew ew ew
# ugly naked guy got thighmaster
# anybody seen engagement ring
# oh god oh god oh god oh god oh god oh god  starts look couch cushions
# oh like dreading tomorrow having  hi barry remember girl veil stomped heart entire family oh god gon na return ring ring makes harder
# easy rach find wo
# doy probably right lost
# lot doy days
# know morning know kitchen
# looks lasagne realizes ohhhhh mad
# gave job starts examin lasagne glass pan
# oh look straight noodles
# monica know look engagement ring lasagne
# standing outside door  hi
# wh  wha  w
# yeah hours right enters
# kinda puts pillow thing perspective huh mon
# carol says susan want involved comfortable involved  basically entirely
# mean presumably biggest job
# want this sonogram thing tomorrow
# idea matter gon na father
# oh martha ludwin daughter gon na tastes snack mmm curry taste
# ross remember ludwins big thing
# oh graduated wants cooking food  know told restaurant
# mom restaurant work restaurant
# know  starts fluff pillow monica fluffed multiple times earlier
# ross come help spaghetti
# oh having spaghetti  easy
# know going sound unbelievably selfish planning bringing baby lesbian thing think heat
# rachel life  ran parents club playing
# gon na tell spent wedding  thousand dollars lot money
# chance leave man altar
# listen mother independent kid  chubby friends fine read room puzzles
# look people like ross need shoot stars museum papers getting published people satisfied staying are telling people cancer
#  read women trying thank god little harmonica problem
# trying desperately change subject ross going stories digs elbow hand news little anecdotes share folks
# pulls hand away okay okay parents look uh realise guys wondering exactly happened carol deal carol lesbian living woman named susan pregnant child susan going raise baby
# yknow people pros know time job
# boy know change parents  boy could ross id want
# yeah speak like high powered driven career type
# right guys kinda got ta clean start leave
# imaginary friend  parents actually preferred
# dya  uh  dya need help
# uh  okay sure thanks hands broom sits
#  um  starts sweep you uh nervous barry tomorrow
# oh  little
# got advice yknow recently been dumped
# wanna steer clear word dumped chances gon na broken shell man yknow try look terrific know hard yknow uh hey barry ring carol susan ob gyn
# oh got carol tomorrow  complicated
# mean think gon na meet somone fall love ross gazes  ross
# oh man thought  leans hand
#  pulls stool hand
# entering sorry late stuck work big dinosaur  thing
# shake hands hello susan carol good shake good shake uh waiting
#  dr oberman okay he
# she course she uh familiar  special situation
# okay great susan gives drink carol im oh
# picks surgical instrament mimes duck quack quack
# ross opens cervix drops horror
# yeah fine fine robbie gon na hours
# im uh okay  look great
# intercom dr farber jason greenstein gagging
# answering intercom right robbie rachel sec
# um uh gon na work yknow yknow like important decisions
# uh uh know okay okay uh baby
# if boy minnie girl
# you minnie hear mouse um um  julia
# sfunny um uh agreed spend rest lives things change roll punches believe julia table
# oh uh went aruba
# went uh  hurt
# mindy maid honour mindy
# yeah uh kind thing
# oh um  grabs forehand got plugs
# got lenses hate sticking finger eye
# month ago wanted hurt wanted hurt life orthodontist
# know right mean thought happy happy mindy happy spit
# um gets ring purse guess belongs thank giving
# hello gon na helen geller
# gon na helen willick
# actually um talked helen willick bunch
# wait minute wha title
# oh sfunny um remember making sperm
# ross actually suggesting helen willick bunch geller cause think borders child abuse
# course  suggesting geller willick bunch
# oh nonononono knows gon na names wind calling geller gets way
# way think way believe ways imagined moment life way yknow uh um hard do
# entering knock knockhow today nausea
# wondering mother  thanks sharing carol uh lie
# you uh yknow gon na dont think involved particular thing right
# dunno  think attack enterprise
# know tilt head left relax eyes kinda looks like old potato
# walks monica standingmonica whaddya think
# pushes starts cry oh shut
# phone hi mindy hi rachel yeah fine saw barry today oh yeah yeah told okay hope happy oh oh mind yknow works guys end getting married having kids everything hope old hairline old nose slams phone okay know cheap shot feel better
# um good walked subway said
# uh loosely translated means naked
# like dating language yknow like means
# nice guy means gon na dating leather wearing alcoholics complaining
# yknow um think people means ha ha
# yeah like kid parents dog sleep tell went live farm
# funny uh parents actually uh send dog live farm
# wh hello millners farm connecticut millners unbelievable farm horses rabbits chase was w  oh god chi chi
# warden minutes pain live knowledge sent honest man die
# okay whaddya want damone huh
# wanna cell cause cell smoke
# think probably damone smokes cell
# alright try taking puff
# fine fine look wanna
# think cigarette think thing missing hand holding feel right feel complete
# nah alright smoke takes puff oh   god continues smoke
# distance tip guy thumb tip index finger
# carrying tray drinks alright tell tell starts handing decaf cappucino joey  coffee black  late  iced tea getting pretty good
# yeah no just worked bank
# just okay going mail open monthly know statement
# oh satan minions work
# earn kept like stealing
# yeah spent like shopping
# okay okay let bought great pair shoes know hear step took happy okay skipping
# okay id just able enjoy like giant karmic debt
# oh believe good years
# hold second alright think went time quit
# okay time wo quit
# right putting putting drops phoebe coffee
# alright gon na change got date
# sgoing pretty good yknow nice having fun
# let today monday
# talking love schhteve schhteve schhexy  sorry
# look know feel chance figure
# mean let meet mean bring guy home minutes mean like coyotes picking weak members herd
# listen seen fair share bad beef tell terrible thing mean friends looking
# know wish bring guy home actually liked
# realise odds happening little slimmer meet guy
# yeah know chi chi
# shouts chandler chandler promise good
# come filter tipped little buddy stay outside
# dear ms buffay thank calling attention error credited account dollars sorry inconvenience hope accept this searches purse football phone free gift believe thousand dollars football phone
# okay good remember like
# hi alan everybody everybody alan
# alan thanks tomorrow alan exits okay okay let let alan bashing begin gon na shot hmm
#  let start way kept picking at sorry loved
# wait minute talking going
# notice  spreads thumb index finger
# know great way smile kinda crooked
# yes yes like man shoe
# nursery rhyme crooked man crooked smile lived shoe
#  think alan yardstick future boyfriends measured
# future boyfriends nono th think yknow
# oh yeah marry david hasselhof impression know gon na parties right impression
# unbelievable like bugs bunny cartoon bugs playing positions right instead bugs base alan second base alan base
# mean like like team
# yep sure showed hassidic jewellers thing softball
# ask guys question dyou think alan maybe
#  dunno little alan
# yeah uh innate alan ness adore
# yes left ys cause yknow uh searches purse
# like thousand dollars football phone
# opens envelope phoebe given oh god money
# like tin foil hat
# cause need okay thanks
# okay alright buy soda okay
# change phoebe sure wanna pretzel
# know know opened floating like tiny little hitch hiker
# maybe contest yknow like collect
# flaw big deal like joey constant knuckle cracking annoying ross pronouncing single word monica snort laughs mean hell thing  accept flaws accept
#  knuckle cracking bother everybody
# like little annoying like phoebe chews hair
# oh listen pheebs think endearing
# know wrong speaking correctly
# yeah cause actually ordered
# ohh ho hooohhh hair comes gloves come
# okay  going guy friends like
# waitwait  talking coyotes right cow got
# believe  yknow feel thing mean feel thing feel thing
# honey  feel thing listen feel guy monica dump
# know  gon na hard
# hey yknow guys cancer emphysema heart disease line smoking cool know
# holding phone chandler chandler alan wants speak
# taking phone hey buddy oh told huh yeah yeah big  true  gee yknow one like okay thanks hands phone stubs cigarette
# ross wandered god good
# ooh lambchop old sock sock hand thirty years talking
# okay think time change somebody nicotine patch
# joey ate stick gum killed think wrong
# finishing changing chandler nicotine patch ygo
# deadpan ooh alive pleasure
# hey pheebs gon na rest pop tart  pheebs
# want rest pop tart
# sorry  yknow stupid soda people gave seven thousand dollars thumb
# way stepped gum  universe
# dragged monica gotten shower going
# nicer gets wear underwear
# oh god hurriedly closes legs
# turns tv okay
# wait wait getting deja vu
# okay its alan know mean easy way  uh  decided break alan
# nononono   things change people change
# know  let guard start care just i starts chewing hair
# but fair fair alan fair
# wants fair yknow want things yknow way
# sarcastic oh sorry feel better
# tearful believe mean holidays coming up wanted meet family
# guys gon na okay
# hey hey fine gon na need little time
# yeah sorry got ta tell little relieved
# yeah great time  stand friends
# remember went central park rented boats  fun
# yeah row like viking
# said gon na miss guys dubious look
# rough day huh  cmere sits ross strokes forehead
# leaving care care game weak got ta smoke got ta smoke
# shouting leaves smoke seven thousand dollars
# okay okay omnipotent day want um world peace hunger good things rain forest  bigger boobs
# yeah  took chandler
# uh omnipotent day  omnipotent forever
# guy mocking wish wish wishes joey enters
# hey joey hi hey buddy
# hey little joey dead got reason live
# waking startling oh  hi
# grandmother new boyfriend kind insecure bed oh deaf constantly like having reassure having good time idea loud
# want stay rachel tonight
#  ninety ninety ninety seven told steps place
# got waaaay free time
# ross hey birthday boy ross check hockey tickets rangers penguins tonight garden taking
# love man kisses ross
# funny birthday seven months ago
# guessing extra ticket decide got bring date
# oh god oh today twentieth october twentieth
# days halloween  good costumes gone
# today day carol  consummated physical relationship joey puzzled sex  know id better pass game think gon na home think ex wife lesbian lover
# trying stop ross leaving cm ross joey ice guys night cm whaddya big guy pretending punch stomach huh huh huh
# alright alright maybe mind promise buy big thumb finger
# look look look look look pay check look window hi
# remember day got pay check cave mines people killed
# god exciting earned wiped tables steamed milk totallyopens envelopenot worth fica getting money mean what chandler look
# oh fine yeah job
# oh way great service tonight
# hockey leave blocked rachel friends leslie kiki joanne guys pause stare hockey hockey guys
# oh god rachel leslie kiki joanne scream hug
# phoebe swear seen birds wild kingdom
# city shopping mom said work aaand true
# look apron look like play
# pregnant leslie look big believe
# guess dad making partner firm points scream
# subject news  holds finger engagement ring scream
# monica look look elbows scream
#  poulet passes leetch passes joey
# leetch spots messier crease pass kicks ross ross staring shop window
# brief time messier stops look women shoes
# carol wearing boots like night we first yknow fact uh tookem cause we chandler look sorry sorry
# points peach pit night uh had
# actually nectarines basically
# uh got dressed  walked the looks realises points the bus stop  fine
# hey woman got ass like carol turn stare thought trying find stuff
# cm guys tell dirt
# biggest news dumping barry altar
# alright let talk reality second
# okay waitressing  um  write specials specials board uh  uh  uh dead flowers vase  oh um artelle lets little chocolate blobbies cookies
# hey rach friends phoebe scream okay like tiki death punch pours contents blender glasses
# okay grabs blender starts drink
# thought phoebe staying tonight kinda like slumber party thing got trashy magazines got cookie dough got twister  phone rings monica answers
# ooh ooh brought operation um lost tweezers operate prep guy
# uh rach visa card people
# oh god ask want
# phone tell reference listens yes hold rachel um unusual activity account
# unusual activity look wanna okay
# wanna know okay okay  wanna know okay okay let let fica guys took money know getting married getting promoted getting pregnant getting coffee sounds like okay okay tell okay okay
# pauses phone uh rachel left building
# alright cm miserably let play twister
# squeezing past people sorry sorry  uh oh
# ice night carol plastic seats thousand angry pittsburgh fans
# actually saying looks like sitting mention ice night  frost
# cm sit sit sit
# feel great amazing independence thing
# monica amazing gave like
# yeah right gave got magic beans woke big plant outside window possibilities stuff  lived village live village
# okay pheebs pheebs jack gave cow gave orthodontist okay know know love him
# oh jack love cow
# plan yknow clear figured kinda like
# mean half time know going got ta figure point gon na come gon na  un floopy
# okay monica if come
# oh  cause   like question
# okay guys magic beans mean got  beans
# get yesss laughing ya pal
# ross buddy need bunch toothless guys hitting sticks
# hey look tv thing
# holds handshe phone says number completely satisfied candy bar completely satisfied
# listen kind emergency guess know predicament room receptionist glares
# phone hold chandler fill sit tosses forms
# jumping feet look wanna trouble okay lot pain alright face dented
# hey this gives look guys heyy
# sorry guys mean bring
# right plan knock door
# yelling outside pizza guy
# thank god food goes answer door
# hi uh mushroom green pepper onion
# miserably ordered  ordered fat free crust extra cheese
# wait gstephanopoulos man dad gon na kill
# leaping couch runs wait gstephanopoulos
# yeah goes street given oh bonehead bonehead
# wait small mediterranean guy curiously intelligent good looks
# wearing stunning blue suit
# nuts got george stephanopoulos pizza rachel pays monica grabs binoculars runs window
# uh pheebs george snuffalopagus
# oh wanna lemme lemme runs takes binoculars
# white house adviser clinton campaign guy great hair sexy smile cute butt
# oh little guy oh love
# ooh wait  wait woman
# oh wait walking floor  walking  walking  going pizza yelling hey bitch phoebe covers mouth hand walks away window
# excuse look hour lot people sick friend gone mean guy toe thing sleeping slides gladd panel chandler talks loud voice oh cm dora mad  know said things mean mean love waiting room yknow feel like lost  slides panel turns takes surprise ba
# oh maybe theyre napping
# whaddya think george like
# yeah think draw then do preppy animal
# remember moonlight coming window face incredible glow
# yes moon glow magical feeling part painkillers
# right big deal today slept time slept seven years
# look little complicated
# left likes women left woman likes women
# little louder okay think man twelfth floor coma hear
# time carol  mumbles
# carol ross gives look oh
# life onehe gets look toooh
# whoah boy hockey big mistake bunch stuff tonight
# okay okay got remember vegetarian pate loved
# goose vegetable  ha haaaah
# oh oh oh okay fine fine feel bad sleeping jason hurley
# okay okay okay got sits cushion leaning falls balcony anyway valentine tommy rollerson left locker
# hello like gon na send phoebe big girl
# big girls pee pants seventh grade
# laughing laugh monica rachel start squabble
# oh george baby drop towel
# yeah drop drop towel drop thepausewowww
# man believe sex woman
# think great yknow sweet romantic
# kidding guy freak  ross enters camera
# hi wearing piece steel bandaged nose tosses forms reception desk
# oh thought great silence lambs oh come admit things considered fun tonight
# fun fun tell specifically fun puck
# kid  kid excuse uh puck
# found finders keepers losers weepers ross looks chandler help
# kid oh yeah rubber glue whateverto chandlercant kid listen uh gimme puck
# hey hey rough holding er
# tries snatch kid puck files grasp knocks receptionist
# spinning okay monica right foot red
# thanks guy nods leaves
# okay pheebs right hand blue phoebe bend overgood joey stares butt appreciatively
# hello oh uh rachel visa card people
# alright phone yes rachel
# nooo grabs phone chandler takes place mat phone hello listens oh yeah know listens oh thanks okay
# phone got magic beans listens mind
# left left aww collapse
# phone ohhh  fine
# big deal amazing ok reach little maneuver bam bra right sleeve right far concerned guy comes close right
# come guys pee standing
# ok know blows mind women breasts time want look work
# oh ok know way guys mean things care
# saturday night big night date night saturday night sat ur day night
# oh right right shut
# chandler likes breaking got ta
# know hard know mean sitting idea happening finally courage horrible awkward moment handed note
# break man stop calling
# oh thanks think feel like gangin
# mean break janice break tony
# yeah know sweet fun anymore know know hunger strike know
# oh yeah week wonderful nutty chocolatey kind cakey pie thing rachel gives dirty look fine
# father wants mercedes convertible
# yeah mercedes home oh horrible called young lady
# ooh hate father calls
# oh yeah yeah actually got extended disco version choruses
# rhythmically uh huh uh huh
# wow dumped obviously agrees
# yeah ok wanna eager mississippi mississippi mississippi pretty cool walks hey angela
# wearing dress accents boobs
# uh rachel uh tonight
# oh big glamour night monica laundorama
# oh uh wanna hear freaky coincidence guess laundry
# clear hey um join
# yes laundry room building um  rat problem apparently attracted dryer sheets goin fine comin  fluffy sevenish
# bob great smart sophisticated real job auditions month actor bob
# come great fun stuff like talking
# yeah sorry joe said let friends guess
# fine fine dinner tonight know friends
# know bob girlfriend uh uh monica
# monica tellin guy perfect
# forget cousin belch alphabet
# come guy great bob angela  brother smart sophisticated real job auditions month actor bob
# looking window oh god help
# ugly naked guy laying kitchen tile eww
# eww look asking favor brother maybe angela come
# proud know huge mistake broken help
# phone ok bye hangs monica coming gon na rachel
# oh hold camper sure thought thing
# rachel date going date
# saying shave pick wine
# wanna rethink dirty underwear basically time gon na underwearyou want dirty
# oh uh fabric softener
# ok ok wrong snuggles says sensitive warm kinda guy know like warm fuzzy bear ok pick way
# thank bob guy look like tall short
# oh god joey know guy horribly
#  horribly attractive shutting
# great maybe tomorrow rent car run puppies
# oh god glad called supremely awful day
# hey good espresso latte
# got proofs photo shoot know little vegetables pretty sucked blew rest day went shopping  looks bags  got looking looking looking got
# got  pulls pair socks
# knew rockys figured know wear bullwinkle bullwinkle wear rocky rocky mix match moose squirrel want
# gon na espresso latte
# oh yeah hug looked pretty brutal
# oh scuse kinda machine
# oh sorry basket pretty unfortunately suds
# hi uh horrible woman took machine
# suds excuse hold second woman friend machine
# hey hey hey stuff
# hey hey hey rule know
# crowd laundromat right rachel ok let laundry
# sweet gentle uh  uh  oh hey uh need detergent
# uberveiss new german extra tough
# rach uh gon na separate
# oh god oh like total laundry spaz mean supposed use like machine shirts machine pants
# know people ok caught laundry virgin
# uh worry use gentle cycle ok um basically wanna use machine whites nother machine colors uh uh delicates bras panty things
# holds pair panties ross ok white cotton panties whites delicates
# visibly nervous uh judgment
# joey cute angela bob guys grow
# lucky man know miss cute nibbly noise eats like happy little squirrel weasel
# oh yeah yeah listen
# yeah gon na bed sexually
# got ta tell bob terrific
# great meet guy smart funny emotional age like
# wow brother told lost virginity
# ok like pulling band aid fast wound exposed
# janice hi janice ok think anymore janice
# right gets extremely wound begins try calm stop stop stop
# ok know gon na sound stupid feel know actually laundry
# sound stupid know like time dinner carol left buzzer washer goes sorry time ross  opens washer uh oh
# wanting tell uh oh uh oh laundry uh song laundry song sing singing uh oh laundry uh oh uh oh
# right right left red sock whites kinda pink
# yeah uh red sock red sorry upset happen
# happened oh god gon na look like big marshmallow peep father right live laundry
# went wrong underdog head inflate um head like flopping broadway right thinking  inappropriate um got eye uh joey check light
# hello table like  cocktails appalachia
# close got tongue ear
# oh like gotten little rambunctious ross
# joey sick disgusting itsnot true
# right look proud ok maybe little
# wait wait wait want want likes
# yeah thinking heads break
# sorry believe stop laughing norman mailer story
# uh waiter plate chicken wings
# thing janice know mean like different like bing bing bing like boom boom chandler flails hand hits janice eye  boom
# oh god sorry ok
# ow um lens lens right
# phoebe hit eye hit eye worst break history world
# oh god chandler downs espresso
# chandler easy easy happy place la la la la la la la
# got clothes clean important
# oh guess looks like jammies
# whoa sorry excuse cart
# yeah 24 inch waist lose things come outta way
# sorry know maybe clear uh cart
# hey hey hey clothes
# hey hey hey hey quit making rules
# right listen missy want cart gon na
# incredible brand new woman ladies gentlemen
# ok um uh clothes dryer ross turns bangs head open dryer door fine fine
# seeing rachel clothes neat idea clothes match gon na
# ripped couple apart kept pieces
# beautiful story hey fine way
# notices head oh sorry
# oh needed time grieve
# reading program ooh look look look look joey picture exciting
# spot seen plays notice fear sense impending doom
# exclamation point title scares gesturing yknow freud freud
# oh shhh shh magic happen
# vell eva veve excellent vork vould pwoblem qviiite clear goes song dance number
# want dingle envy schwang thing tinkle play simply let hang
# anybody feel wanted peel skin body
# staring woman room ross oclock
# sighs gestures explain beautiful woman oclock
# amazing makes women dream look like short fat bald men
# oh yeah opening line excuse blarrglarrghh
# woman like million years
# oh oh yknow beautiful women guys guys
# oh god believe considering  aware tongue
# hi  um  okay word   chandler chandler uh  he clears throat noisily  hi
# yes yes wanted uh  like thankyou goodnight walks calls
# hey play know dance beard
#  hey play know dance beard
# cm guys bad better thing trolls got head
# admitting saw head saw head
# running said yes said yes joey awful play man whoah aurora italian pronounces chand lrr chand lrr think like better way joey oh listen usher gave fishes card pocket
# estelle leonard talent agency wow agency left card maybe wanna sign
# based play  based play
# reading monica palm cause line passion  line
# believe seven seconds asked date went
# oh right right date chand lrr
# unbelievable ive met like amazing life israeli army
#  luckily bullets hit engine block border barely i  talking night long sorry tell stories
# alright got subway right night rode way brooklyn  hell
#  sudden realised yammon
# oh sorry widowed  hopefully
# tell do think husband feel sitting me  sliding foot far pant leg count change pocket
# worry imagine okay okay ethan
# mmmm  ethan  boyfriend
# explain uh kind relationship imagine having husband boyfriend
# work seeing thursday listen story
# listen story mean twisted involved woman like
# yknow trouble way look good stuff fun talking sex responsibility mean guy fantasy
# oh yeah true ross fantasy
# course thinks  yeah yeah
# guys mind going going
# woman need know going people
# yknow monogamy uh tricky concept mean anthropologically speaking
# fine fine alright know
# alright theory forth richard leakey
# greeting way cause like
# look cleaned windows floors  attachments vacuum little round bristles know
# oh yeah knows supposed ask
# clean looks great terrific
#  oh moved green ottoman
# dunno  thought looked better i extra seat coffee table
# yeah yeah interesting  yknow fun let looked like old spot moves alright compare let looks good let leave
# rachel believe tried green ottoman
# thank god try fan magazines mean scratch eyes right
# yeah monica remember lived like little yknow psycho ree ree ree ree
# oh cm kids raggedy ann doll raggedy
# okay responsible organised hey kook
# alright madcap gal try imagine phone bill arrives pay right away
# kook instead wait send notice
# okay uh let grocery shopping buy laundry detergent easy pour spout
# left glass coffee table coaster cold drink hot day little beads condensation inching way closer closer surface wood
# stop  oh god true
# ree ree ree ree ree
# phone uh huh  uh huh  oh god okay okay hangs agent tosses catches phone agent gotten job  new al pacino movie
# believe al pacino guy reason actor order pfeeeh order courtroom order
#  mah mah mah
#  butt double kay play al pacino butt alright goes shower then butt
# trying laugh oh god
# cm guys real movie al pacino big
# oh terrific   yknow deserve years struggling finally able crack way showbusiness
# okay okay fine jokes care big break
# right right  gon na invite big opening
# alright alright alright
# whaddya think today big day
# oh god okay bathroom use want tell
# cm roommates goes bathroom screams runs eyes eyes
# oh monica hey listen wanna borrow coupla things aurora spent night wanna breakfast
# oh got night huh
# yeah minutes ethan yknow  starts raid fridge
# ooh sense little bit resentment
# resentment believe worth kay yknow relationship key moments know remember rest life every single second like aurora  wasted thirty talking people uh  monica help door armloads stuff
# sure oh um chandler yknow old monica remind scrub teflon pan plastic brush  gon na
# phone  dammit hire girl hangs phone okay everybody ready
# uh listen wanna thank great opportunity
# right okay losing robe takes robe robe lost
# okay everybody like let roll  water working shower starts   action
# cut hey butt guy hell
# oh way guy upset yknow mean wife dead brother missing  think butt angry
# think butt like shot lunch rolling  water working  action  cut
# going quiet desperation ask
# god love fingers
# actually meant fingers look em look happy
# moves chandler arm look watch oh god late starts
# oh nonononononnononono  kisses pulls
# getting dressing sorry waiting
# thought thought talked rick
# ethan got spend day
# know moments years come regret asking following question but andrew
# oh saying completely fulfilled rick ethan
# yknow women kill guys like
# talk laugh love feeling obligated  tonight thought wanted
#  yknow wants like guys yknow mean guy going shut great guy actually guy wells time grinch heart grows sizes breaks measuring device  saying yknow hard
# know listen exactly let finish
# gets leave change mind
# sorry guy runs lips
# look way dumped right mean woman unbelievably sexy beautiful intelligent unattainable  tell
# hey waitwait guy plays butt new al pacino movie
# felt like big guy moment
# yeah said acted told everybody everybody gon na theatre expecting
# oh joey know gon na able tell
# yknow crappy plays years finally shot blow
# yeah mean  think shot yknow know shot  feel like shot
# think shot mean think shot believe big things gon na happen got ta thinking day kid gon na run friends got got gon na joey tribbiani ass
# sorry joey gon na bed guys
# uh mon gon na leave shoes
# casually strewn reckless haphazard manner
# matter em tomorrow goes room
# hums gives head bothers shoes stupid prove gon na  know wake early  need help buries head pillow
# everybody shh shhh uhhh  central perk proud present music miss phoebe buffay
# hi um want start song moment suddenly realize life ok plays chord lights ok thank
# wow cool guys entire city blacked
# mom says manhattan parts brooklyn queens idea coming
# phone pants sweater mom gon na meet blackout power company guys eligible looters talk later ok hangs
# borrow phone want apartment check grandma monica number
# oh god victoria secret model  goodacre
# right jill jill goodacre oh god trapped atm vestibule jill goodacre pause vestibule maybe atrium oh yeah focus idiot
# phone yeah fine stuck bank atm vestibule
# jill says vestibule  going vestibule
# phone fine  know guy
# oh guy guy hey jill saw guy night yes guy
# officiating tonight blackout rabbi tribbiani
# chandler old roomate jewish candles  happy chanukah
# window eww look ugly naked guy lit bunch candles
# alright alright alright fourteen half minutes said word oh god contact smile
# awkwardly like somebody offering phone
# yeah 300 guys went high school yeah thanks takes phone
# yeah fine trying cover saying trppd atm vstbl wth jll gdcr
# trppd  atm vstbl  wth jll gdcr
# trppd  atm vstbl  wth jll gdcr
# oh god trapped atm vestibule jill goodacre phone chandler listen says intentionally garbled
# yeah like thought entered mind
# ok ok senior year college  pool table
# ok  weirdest place  women room second floor new york city public library
# disneyland 1989 small world
# ride broke carol went couple mechanical dutch children  fixed ride asked return magic kingdom
# oh alright weirdest place  sigh  oh foot bed
# relationship kind passion know somebody right middle theme park
# barry kiss miniature golf course
# mean think people life having kind
# probably know tell passion way overrated
# eventually kind  burns hopefully left trust security  case ex wife lesbianism know people miss passion  thing good stuff
# um  think going
# uh uh  big passion future
# oh ross great playfully rubs head gets
# waited long friend zone
# taking time alright laying groundwork yeah mean day little bit closer
# priesthood look ross telling idea thinking ask soon going end stuck zone forever
# waiting right moment joey looks
# yeeeeaaaahhh messing wine candles moonlight got rachel think  rachel comes room
# shushing   trying hear listen silent hear
# huh agrees looks confused
# oh thanks hell mental note jill goodacre offers gum offers mangled animal carcass
# singing new york city power milk getting sour scary cause stay away dairy  la la la la la la la  writes lyrics
# thanks joey hugs ok
# ok ross goes balcony talk rachel
# ok got promise tell ross told
# phoebe enters better act surprised
# oh stop joey told
# hey look ross thing
# yuh huh know chandler got bitten peacock zoo know crush joey moving monica gestures phoebe shut joey looks surprised pleased looks like second
# ok question actually question  general wondering  ment
# ok goes wanting um
# yes yes right
# oh look little cat small kitten roof ross
# cat jumps shoulders ow
# singing world looking creation explanation find wonders found
# ross bactine wo hurt
# oh poor little tooty scared death find owner
# poor little tooty hall
# know second thought gum perfection jill gives stick gum strange look gum perfection gum perfection said gum nice stick gum perfection loathe
# stops door oh mendels hate living things right
# oh knock door mr heckles answers hi found cat looking owner
# trying hold struggling cat hate sure
# mmm bob buttons bob buttons
# cat runs away oooh bad man
# phoebe rachel leave owe cat
# kitty kitty kitty kitty little kitty kitty kitty kitty kitty kitty kitty
# wow exhales amazement blowing candle
# rolling lucky sixes
# entering paolo arm arm everybody paolo paolo want meet friends monica
# jealous um  paolo come
# oh  italy think
# mean tonight building suddenly lives
# cat  cat turned paolo cat
# funny  joey  rachel keeps touching
# alright looked building find kitty
# oh found paolo cat
# ah know guessing  told  paolo
# italian apparently attracted phoebe
# chewing gum ah let blow bubble bubble good got  boyish charm impish
# nice going imp ok ok need reach mouth chandler slyly grabs gum wall slides mouth
# good save track  grimacing  chewing gum gum oh god oh god choking
# god choking runs gives heimlich gum flies mouth better
# gasping yes  thank
# romantic italian rachel stars
# mocking paolo blah blah blah blah blah blah  blah blaaaaaah
# monica phoebe oh god guys un
# know want bite lip rachel looks wo
# god time smiled  seconds exciting weeks bermuda barry
# know ride mopeds cause heard  stare  oh  right ok
# yknow know totally superficial absolutely common speak language goooooooddddddd
# listen um listen  know  um rachel  kind thing
# technically  sex   point um point  rachel er know  um
# going er  way thing sad
# funny know huge crapweasel
# chandler hour watch easy
# ready swings pen head circle
# oh look look look candle burn 10  time lapse  negative 46 negative 47 negative 48  blows room gets completely dark
# kinda  spooky lights
# maniacal laugh bwah hah hah
# ok guys guys definitive mwwwooooo hah hah
# oh  oh  oh
# hey ross probably best time bring throw party monica
# yes yes thanks letting use phone  saving life
# goodbye chandler great blackout kisses cheek ya
# hi um account number 7143457 uh know got like copy tape
# dehydrated japanese noodles fluorescent lights  better
# question dating anybody met somebody perfect
# ah ysee perfect problem said co dependent self destructive
# okay cute funny hes
# yeah  oh god i just thought good shelley gon na flush toilet  backs room okay goodbye
#  enjoy cup noodles mean ridiculous believe actually thought
# um  yeah mean met yknow thought maybe possibly
# yeah spent phoebe entire birthday party talking breasts figured maybe
# huh uh  rest guys think met
# nono uh yknow college susan sallidor
# cause uh kinda wanted told actually seeing bernie spellman  liked
# dunno cause smart funny
# ross smart funny dyou think
# okay dknow just quality
# oh oh quality good worried guys gon na vague
# hello hello oh rachel paolo calling rome
# oh god calling rome takes phone bon giorno caro mio
# joey calling rome got ta rome
# monica dad beeped quick talking rome showing phoebe chandler talking rome
# hey dad listens oh god ross nana
# doctor says matter hours
# fine fine glad  hair
# okay relax relax gon na looks like boyfriends career cover
# fuzzy little mints purse
# oh  yeah gross oh know loved sweet los stealing from restaurants
# pop pop aunt phyllis
# gbye nana kisses forehead
# yknow nurse said nana passed
# exasperated yes chandler exactly hair
# dunno weird mean know gone feel uh
# hm mean maybe goes mom died feeling like right yknow circles hand right shoulder chandler sitting right draws nervously oh debbie best friend junior high got struck lightning miniature golf course strong debbie vibe use little yellow pencils yknow  miss
# aw hey pheebs want gives pencil
# believe think dead dead gone worm food realises tactlessness  chandler looks gay huh
# yknow dunno debbie hands pencil
# thought gon na closed casket
# listen time comes wanna buried sea
# wanna buried sea looks like fun
# cm day rent boat pack lunch
#  throw body water  gee sound fun
# thinks know says jack geller predictable maybe gone buried sea huh
# sheepish hey look sorry yesterday um
# nono dont worry believe apparently people mistake
# dunno uh
#  quality right great
# yknow shame lowell great couple
# lowell financial services lowell saw
# yeah  sno brian payroll
# uh dknow point gon na set like think set like
# think brian little league
# excuse think brian brian believe
# holding dress inside closet
# shown want mother spend eternity lemon yellow pant suit burgundy
# know pick told wrong
# oh fine choice coming starts climb furniture
# okay um holds pair
# forages okay evening shoe burgundy silver work
# yeah  nana stuff
# mom called morning remind wear hair know ears best feature
# entering hi sorry late find bearings
# sticking foot hm m
# yes paolo sent italy
# entering chandler morning ready
# look nice dressed up  stuff like
# oh cmere sweetheart hugs yknow think time start night cream
# overcoat sounds remarkably like brent mussberger
# check giants cowboys pocket tv
# watching football game funeral
# pre game gon na watch reception
# oh new paolo shoes
# god great day  weather wise
# know uh air trees  nana gone uh dunno life aff looking going falls open grave
# fine  having worst fear realised
# okay worry checking muscle spasm  huh
# sweetie took golfing accident hands ross bottle pills turns monica pats hair ears
# sorry hi dorothy daughter
# hi chandler idea dorothy
# feel great feel great fleel great
# wow pills worked huh
# second two woooo  love guys guys greatest love sister kisses monica love pheebs  hugs
# hugs listen man wanna gay gay matter
# turns friend right walk leave chandler
# rachel rachel rachel sits love
# humouring oh know love
# oh  passes slumps
# hides tv earphone uh  hearing disability
# seventeen fourteen giants  minutes
# trapped ross pheebs maybe hand cracker
# hearing honey glazed ham spend flowers spent saying wasting money need flowers dead
# know like grow critical single thing
# telling wonder mother turned positive life affirming person
# wonder tell mom mean right tell
# drove crazy picking little detail like hair  example
# think things better told truth
#  think things better left unsaid think nicer people
# reaches fiddle monica hair realises earrings look lovely
# hey little naked guy
# aww look little thing
# yes yes fine penis grown ups
# oh nana right middle reads gang java joe
# wow monica look like grandmother old
# let 1939  yeah 24 25
# looks like fun gang look smile
# ooh look look look look look got monica naked
# looking nono uh trying
# like mardi gras paper mache heads bout
# good good listen heh dunno shelley told uh
# pretty time kind  radar
# speaking people way friend brian payroll
# yup waaay league exits
# league brian brian enters wanted brian brian sees hey brian
# terry know worked long wondering think possible got 100 advance salary
# spend thanksgiving family year skiing vail normally father pays ticket sort started independence thing know actually took job
# rachel rachel sweetheart terrible terrible waitress awful
# ok hear sayin um trying hard think better anybody need coffee place raises hand oh look
# excuse sir hi come time wondering think possibility advance tips
# ok ok fine fine hey sorry spill picks tip leaves 9850
# hey ross know mom dad going puerto rico thanksgiving
# getting upset calling mom
# cry help department wearing makeup
# yes today officially joey tribbiani actor slash model
# funny cause thinking look like joey tribbiani man slash woman
# know posters city free clinic
# oh wow gon na healthy healthy healthy guys
# know asthma guy cute
# hear lyme disease open  crosses fingers
# good luck man hope
# monica right huh thanksgiving
# ok tell cook dinner place like mom
# know actually supposed  ross looks sheepishly work lumps joey going home right
# assume chandler boycotting pilgrim holidays
# phoebe gon na grandma
# ...
# going believe happened today
# ralph lauren called offered money
# yeah weirdest thing zelner called said thank ron  know department guy
# great staying new york
# hesitant ye ah yeah know money great certainly easier choice
# yeah know looking forward going paris sure know excited working fashion capital world ooh absolutely  oh  yeah know  fine fine going job pretty gotten possibly  sits ross stunned hear follows example
# uhm  idea excited paris uhm mean said scared
# yeah mean good scared know like moved new york scared uhm found gonna emma scared   fine gon na good stare
# told zelner come
# picks skull carnivore table puts bag brought pterodactyl egg zelner sure understand
# right right gon na gon na paris
# yeah going paris thank ross
# yeah yeah oh hug
# thank coming today pay respects wonderful agent beautiful woman  joey looks photograph  inside estelle clients like words joey looks notes man chewing dude speech man swallows looks joey entertaining al zebooker everybody applauds al shows left mouth
# right right right let play time ok remember win paris
# ok believe risking right joe remember rules heads win tails lose
# thought throw little going away party seven
# hey rach leaving tomorrow packing
# oh yeah right took shower morning threw towel floor oh god hurts joke
# know  honey seriously luggage taking bedroom emma paris stuff boxes having shipped sandwich plane
# ok good work pause carry ons
# oh need takes bag travel documents counter organized order needing
# oh god left teach hug
# maybe opens bag oh oh oh packed boxes
# let help start opening boxes
# point stop funny took passport
# oh wow believe like weeks away
# mind touching belly right hand kind blocking baby gon na come
# hey erica welcome town pause wow look big gotten
# oh ok afraid people think fat big breasts
# brought pause realize coming soon
# hey couple weeks wo able travel
# yeah wanted know doctors settled hotel
# moving couple days sense
# plus hotels fun room little fridge free snacks
# erica things free fact highest mark ups consumer product
# ross giving baby eat wants
# oh man believe guys leaving place
# oh know know hey know want lease nana
# place sad plus month cost feed joey
# hey chandler talked catching movie
# oh time want help joey pack guest room
# mhm balance things packing sexy cheerleader comedy
# mhm helpful brother creepy loner teen movie
# try feel thing ross starts punching
# right rachel party couple hours lot ross got geller blood charge yahoos
# got monica leaves ross closes door right right got ta grabs bag styrofoam peanuts let styrofoam peanuts pants kick
# guys right work stuff closet joey pack em ross pack joey packs
# holding pair furry handcuffs hell
# hey handcuffs fur line nice know guys ya
# chandler sister understand bums
# mhm maybe boyfriend maybe richard
# use richard kinky naked dance  scarves
# bumming hard guys bumming hard
# oh gig kinda like married rock star know husband gig
# oh playing organ children roller skating party
# wow spread pause stuff
# thought great opportunity use food want new house enjoy smoke oyster casserole breakfast cereal crust kidney beans juices dessert questionable orange
# oh putting emma second
# hit leaving kind emotional set ok
# ok gon na fine
# oh man believe actually leaving gon na goodbye rachel
# know big life feels like melrose place got cancelled ross joey looks puzzled mean  oh forget miss melrose place
# loses seven coin tosses row head wins tails lose stops starts realizing wait minute
# forgot pick dry cleaning
# guys gon na come visit right
# yes know months statute limitations runs travel internationally
# know uhm goodbye stuff wanted gon na save end night come guest room
# huh guess rachel putting bubble wrap phoebe punching
# oh pheebs know start
# ok know supposed going away presents takes pocket
# oh oh holding present transparent bag white stick
# cotton swab bit saliva perfect cloning process use dna create pheebs
# gon na throw away thank gesture
# chandler bedroom found holds furry handcuffs pillow
# oh yes decided leave case richard stops wanna engage little light bondage moustache play
# oh yeah right good luck getting scarf dance
# rachel  handcuffs interesting looks excited
# look excited anymore played
# love hug  turn  know  french bitch hug
# right gon na better going
# monica wearing waterproof mascara
# oh screwed monica goes guest room
# gon na goodbye individually
# kidding oh god
# yeah know gon na worse  god  ross ready crying
# oh man going able handle pause know students feel end year act giving bad evaluations
# mon  okay  got ta  gon na  amazing things happened years happened like sister
# know mean like sister
# starts crying speaking time making impossible understand saying know gon na
# having problem best friend
#    saying understood
# joey oh took monica  crier family oh god maybe wo talk looks like deep converstation oh thing said thing think thing
# rachel uh rach  think belongs shows cuffs
# laughs oh sure gon na miss pretending laugh weird jokes
#   found old room
# maybe monica use
# think forgetting kinkiest resident room
#  look flimsy come good god try hang guy waterpipe snap like piece licorice
# sure phoebe handcuff guys waterpipes
# think mike giggles chandler looks aghast
# let  gon na uncomfortable probably stupid joke  want  love  gon na miss sad leaving
# mushy oh know let love hug
# ooh tight  blows raspberry hug ends sorry chance
# oh definately cried like years
# cried yesterday oclock news
# old woman scammed mechanic
# god believe saved looking balcony taking long
# know god joey handling suprisingly
# oh  holding ross shoulder
# think gon na pats ross looks surprised
# oh guys amazing night thank love good night
# maybe thought history know implicit
# right let think mean got explanation uh  mad
# know maybe spent talk pretty intense
# annoyed kay  mean deserve mean tears cursory hug joey gives ross hug joey lets
# owe goodbye mean got pride
# talking agitated angry gets goodbye got goodbye huh best friends uh baby oh wait minute wait minute things
# oh maybe giving credit uh mean difficult goodbye people uh goodbye goodbye goodbye goodbye good  makes choking noises physically impossible know believe want leave things good time paris leaves apartment rachel looks kind desperate
# right think gon na head
# thought going home bed sensing fun
# moving couple days got lot packing great guys pitch
# joey finish guest room
# oh yeah yeah good idea mimes hitting head fist
# oh phoebe gon na help
# joey cool goes guest bedroom
# okay gon na start kitchen plates plate protectors stacked box silverware gets bundled rubber bands bubble wrapped got
# good need careful efficient remember harsh wrong
# hey mon think figured handcuffs
# cleaning closet found pictures
# oh god let look pictures
# oh okay went movie cousin dinner went place  ooh  looks likes pain holding belly hoo  ooh  amazing cheeseburgers
# yeah know maybe ate getting stomach aches come like minutes
# right chandler coats erica let phoebe joey packing oh god gon na baby right gon na baby oh god were gonna baby oh god oh god got sit got sit ooh hyperventilating
# honey gon na okay
# okay okay  okay feel little better
# oh  yes sure oh honey let okay bye
# chandler wait wait wait
# second find got cheeseburger
# believe years know thing
# damn hard ross begin explain gon na miss think seeing day makes want  okay think goodbye mean everybody wrong mean right goodbye  oh
# okay starts stuff styrofoam peanuts joey pants
# little little stuffs pants joey assesses little  right okay right let
# yeah right best shot
# pain work  falls knees head floor
# yeah know maybe ate getting stomach aches come like minutes
# think goodbye mean everybody wrong mean
# shh  sleep home
# yeah guy work gave sex dummies joke
# breathe breathe breathe  good
# time said like dracula scared want ice chips
# exactly kind social situation comfortable
# kind social situation comfortable
# fine nah wo minutes
# ah  plans summer
# know maybe church camp
# hah wanna mention wonder worse know going labor getting kicked nuts
# interesting know know experience
# life great unanswerable questions mean knows maybe painful things like
# house warming present monica chandler
# uh huh named chick jr duck jr
# yeah figure love new house know big backyard old special farm chandler took chick duck
# yeah shame people visit
# yeah erica went labor night monica chandler hospital right
# yeah definite feeling gon na girl
# phoebe sure ben gon na girl
# uh think asleep hey hey guys night pretty pissed
# uh yknow worked things
# hey kiss tell sex shut totally
# oh  know talk
# know incredible mean felt right holding mean wanted let know yeah wanna
# oh like best day guys monica chandler getting baby chicks ducks world oh feel like musical singing daa raa  sun comes bright beaming moon comes
# uh guys mind giving minute
# sure yeah eye chick duck
# chick duck die
# interrupting dive yeah dove head fun farm
# woke today biggest smile face
# know  know like things think gon na happen want
# uh huh know perfect way goodbye hugs ross looks crushed
# uh huh think time kick nuts worse
# oh oh god beautiful head seen chandler
# chandler wanna miss birth child miracle life
# alright wow disgusting miracle
# start pushing come shoulders
# emotional baby beautiful little baby stuff gon na pretend
# like cut umbilical cord
# son oh hey handsome oh gon na love woman gon na good chandler verge tears oh lucky
# erica oh god beautiful thank
# oh yeah faces people know
# believe know twins happened
# gosh makes feel special good
# doctor wait know twins
# yeah paperwork got clinic ohio
# think mention heartbeats thought baby kept saying heartbeats strong thought good cause having baby
# twins actually run family
# uh huh join wo okay like option
# half medallion years later find reunited mean great day everybody
# okay person adopts horrible
# yeah hear king looking adopt
# matter waited long care babies care babies care entire cast comes taking home children
# smiles okay shhh
# come erica start pushing
# said perfect way goodbye
# ross got tell feel
# dude trying speak language
# ross rachel know wanna feel differently
# telling oh okay musical good convincing song singing bam bam answer bam bam let love fly away bam bam bam bam
# hi dropped emma mom
# decided ahead set mom bring emma paris sunday
# wow hour flight year old good luck mom
# kidding hours mother talking atkins good luck emma
# alright know right tell feel
#  know leaving tonight tell love
#  know changes plans thought know
# touched gunther  oh  love probably way caf having coffee man hair brighter sun think aw
# oh  bye guys
# maybe like people lived apartments years day pushed vagina meet
# wanna tell decided girl baby erica
# gon na rest glad picked guys gon na great parents chandler
# oh look little bunnies
#  welcome home sign baby
# going shoot guys saw happened gunther look like fun
# compare gunther mean sure sexy obvious way relationship slept night
# yeah wants pretty clear
# yeah know mean mean
# look gon na tell okay seeing got time
# going paris going meet somebody know hot guys paris  city gunthers
# oh little time work better
# know baby read mike
# hi guys car service got believe home catch stupid plane wanna baby
# monica called cab said minute apparently big surprise
# yeah sound happy cause friend ethel baby born teeny tiny beard
# monica hey big surprise
# okay okay awkward question hospital knows took right
# points baby holding boy points baby chandler holding girl
# hey pregnant girl erica
# yeah shame spend time
# yeah named boy jack dad
# aw gon na happy
# oh jack bing love ooh sounds like 40s newspaper guy know jack bing morning gazette gon na blow story wide open
# oh gosh wow beautiful
# oh yeah tell try slip coat
# yeah ooh teach sing like von trapp family nazis sounds kinda dull
# oh guys believe leave gon na miss plane
# oh sorry gon na watch attempt handle alright goodbye guys love
# want know  night  forget
# alright okay au revoir oh gon na hate
# yeah know  look got ta  got ta think night way okay maybe maybe sleeping perfect way goodbye
# maybe okay know maybe maybe better way mean mean trying long maybe different continents  looks phoebe right
# maybe actually know finally
# wait wait coat coat
# ross ross think going
# know  look shoots wo spend rest life wondering happened coat
# bring cab downstairs drive airport
# okay guys wish luck
# good luck good luck
# okay hit engine explode know better thrown car
# hey law says accept fare
# alright got ta report medallion number
# oh hey hey guys house warming present
# ah  chick jr duck jr hide mama
# old woman bicycle alive
# oh god phoebe slow
# yes wanna die cab
# screaming toll booth bucks quarters glove compartment
# quack quack tweet tweet quack quack tweet tweet quack quack tweet tweet quack quack tweet tweet quack tweet quack
# wondering taking long gift understand
# okay wanted surprise house warming gift got baby chick baby duck
# oh great want new house infants bird feces
# yeah yeah jumped table cause gone
# actually gon na check twins
# sorry know look chinese food floor
# okay let find birds
# oh oh maybe lure know birdcalls
# maybe tip table little
# know  foosball table
# right know choice like said sci fi movie gotten men sacrifice important thing life time machine
# talk rachel took ride death cab
# gon na walk gate chased airport
# okay walk slower great
# french accent madame passport
# oh god afraid gon na remember high school french understood word said
# oh shoot oh believe
# madame boarding pass
# oh okay find remember seat 32c bra size
# madame boarding pass
# okay fine know 36d having problem
# fine tickets need tickets
# oh shoot damn oh oh found found
# hah found told find face different person
# okay flight 421 paris
# impossible leave 20 minutes
# maybe flight number wrong god
# hey hey listen
# oh god ross believe cute little noises twins making listen
# monica monica monica monica monica
# oh wait wait wait
# monica monica monica monica monica
# precious listen need rachel flight information
# oh okay alright flight 421 leaves 840
# says flight 421 leaves 840 newark airport
# yelling worry guys gon na
# gon na buy tiny bird hearing aids
# okay table given great times guys jordan victor joel  guys guys look good wanna
# know time  touches players says following good game good game good game good game good game good game good game
# yeah stuck inside table
# oh sure got ta hard gimme
# phoebe forget okay newark like hour away way gon na time
# rachel oh good hey way plane
# ross worth caught right airport
# uhm actually  plane
# feeling wrong wrong left philange
# oh honey sure wrong plane
# alright look love minute paris
# oh crazy friend told plane feeling wrong left philange
# worry coming stuff like know right
# plane okay friend feeling wrong left philange
# oh god plane philange
# yeah slowing alright babies girls later
# gon na buy new
# probably nah know gon na wanna play
# aww worried hm guess better things crapping hand huh
# gon na miss little guys nice having birds
# yeah mean got lot going right plus room
# know think set poultry
# thanks man hear guys gon na stay good know cause cause reason come visit
# think reason awkward hug lame cool guy handshake
# uh lame cool guy handshake yeah
# maam assure plane fine
# yes philange fixed matter fact lot extra philanges onboard case
# wow excuse sir boarding pass
# oh god   guys
# know know waited till  stupid okay sorry telling love plane
# hey hey know love know
# waiting ross right sorry sorry
# yeah uh mean eat
# yeah yeah talked got plane
# went home want anybody
# answering machine ross hi got plane feel awful wanted things end expecting sudden saying things   sitting thinking stuff said mean tell love course love love love love oh got ta got ta plane
# answering machine miss sit
# answering machine sorry sorry need plane okay need tell love love
# answering machine miss let plane
# answering machine afraid gon na seat
# answering machine oh miss understand
# answering machine oh come miss way let
# oh god plane plane
# okay cause wanna okay messing wanna mess
# okay careful grandmother careful
# falls truck worst thing
# children look guys home happy place filled love laughter important rent control friggin steal
# hey realise time lived apartment
# wait minute summer college lived grandma tried dancer
# oh honey forgot promised treeger leave keys
# oh gon na okay
# crying guys new house right away time

# %% [markdown]
# The next step is to build the vocabulary of the words and word combinations we want to learn representations from. We choose a subset of the most frequent words and bigrams to represent our corpus.
# - Use the Gensim Phrases package to automatically detect common phrases (bigrams) from a list of lines from the previous step (`min_count=10`). Now words like New_York will be considered as one entity and character names like joey_tribbiani will be recognized.
# - Create a list of words/bigrams with their frequencies and choose the top 15.000 words for the vocabulary, in order to keep the computation time-limited and to choose the most important words.

# %%
from gensim.models.phrases import Phrases
words = [line.split() for line in quotes]
phrases = Phrases(words, min_count=10)
new_lines = [phrases[line] for line in words]
# Out:
# INFO - 01:22:52: collecting all words and their counts
# INFO - 01:22:52: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 01:22:52: PROGRESS: at sentence #10000, processed 83404 words and 63101 word types
# INFO - 01:22:52: PROGRESS: at sentence #20000, processed 169724 words and 111375 word types
# INFO - 01:22:52: PROGRESS: at sentence #30000, processed 254136 words and 155756 word types
# INFO - 01:22:52: collected 160602 token types (unigram + bigrams) from a corpus of 263789 words and 31213 sentences
# INFO - 01:22:52: merged Phrases<160602 vocab, min_count=10, threshold=10.0, max_vocab_size=40000000>
# INFO - 01:22:52: Phrases lifecycle event {'msg': 'built Phrases<160602 vocab, min_count=10, threshold=10.0, max_vocab_size=40000000> in 0.39s', 'datetime': '2023-11-13T01:22:52.736742', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}

# %%
### find the top words for the vocabulary###
# Create a list of words/bigrams with their frequencies
word_freq = {}

for line in new_lines:
    for word in line:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1

vocab = [word for word, freq in sorted(word_freq.items(), key=lambda item: item[1], reverse=True)[:15000]]

# %%
word_freq['central_perk']
# Out:
# 36

# %%
word_freq['joey']
# Out:
# 1893

# %% [markdown]
# ### Subtask 2: Training the Model

# %% [markdown]
# Use the Gensim implementation of Word2Vec to train a model on the scripts. The training can be divided into 3 stages:
#
#
# 1) Set up your model with parameters; define your parameters in such a way that the following conditions are satisfied:
#  - ignore all words that have a total frequency of less than 2.
#  - dimensions of the embeddings: 100
#  - initial learning rate (step size) of 0.03
#  - 20 negative samples
#  - window size 3
#  - the learning rate in the training will decrease as you apply more and more updates. Most of the time when starting with gradient descent the initial steps can be larger, and as we get close to the local minima it is best to use smaller steps to avoid jumping over the local minima. This adjustment is done internally using a learning rate scheduler. Make sure that the smallest learning rate does not go below 0.0001.
#  - set the threshold for configuring which higher-frequency words are randomly down-sampled to 6e-5. This parameter forces the sampling to choose the very frequent words less often in the sampling.
#  - set the hashfunction of the word2vec to the given function.
#  - train on a single worker to make sure you get the same result as ours.

# %%
from gensim.models import Word2Vec
def hash(astring):
    return ord(astring[0])

# %%
w2v = Word2Vec(
    sentences=new_lines,  # The preprocessed quotes with bigrams
    vector_size=100,      # Dimensions of the embeddings
    alpha=0.03,           # Initial learning rate (step size)
    negative=20,          # Number of negative samples
    window=3,             # Window size
    min_count=2,          # Ignore words with frequency less than 2
    sg=1,                 # Skip-gram model (sg=1), you can also use cbow by setting sg=0
    sample=6e-5,          # Down-sample higher-frequency words
    hashfxn=hash,         # Hash function for reproducibility
    workers=1,            # Train on a single worker
    min_alpha=0.0001      # Minimum learning rate
)

# Train the Word2Vec model
#w2v.train(new_lines, total_examples=w2v.corpus_count, epochs=30)
# Out:
# INFO - 01:23:00: collecting all words and their counts
# INFO - 01:23:00: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 01:23:00: PROGRESS: at sentence #10000, processed 80047 words, keeping 9447 word types
# INFO - 01:23:00: PROGRESS: at sentence #20000, processed 162752 words, keeping 13041 word types
# INFO - 01:23:00: PROGRESS: at sentence #30000, processed 243864 words, keeping 16222 word types
# INFO - 01:23:00: collected 16555 word types from a corpus of 253115 raw words and 31213 sentences
# INFO - 01:23:00: Creating a fresh vocabulary
# INFO - 01:23:00: Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 9195 unique words (55.54% of original 16555, drops 7360)', 'datetime': '2023-11-13T01:23:00.912397', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# INFO - 01:23:00: Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 245755 word corpus (97.09% of original 253115, drops 7360)', 'datetime': '2023-11-13T01:23:00.913394', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# INFO - 01:23:00: deleting the raw counts dictionary of 16555 items
# INFO - 01:23:00: sample=6e-05 downsamples 976 most-common words
# INFO - 01:23:00: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 115801.2393707509 word corpus (47.1%% of prior 245755)', 'datetime': '2023-11-13T01:23:00.970979', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# INFO - 01:23:01: estimated required memory for 9195 words and 100 dimensions: 11953500 bytes
# INFO - 01:23:01: resetting layer weights
# INFO - 01:23:01: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-13T01:23:01.065541', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# INFO - 01:23:01: Word2Vec lifecycle event {'msg': 'training model with 1 workers on 9195 vocabulary and 100 features, using sg=1 hs=0 sample=6e-05 negative=20 window=3 shrink_windows=True', 'datetime': '2023-11-13T01:23:01.066546', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# INFO - 01:23:01: EPOCH 0: training on 253115 raw words (115894 effective words) took 0.9s, 131494 effective words/s
# INFO - 01:23:02: EPOCH 1: training on 253115 raw words (115845 effective words) took 0.8s, 144608 effective words/s
# INFO - 01:23:03: EPOCH 2: training on 253115 raw words (116107 effective words) took 1.0s, 119398 effective words/s
# INFO - 01:23:04: EPOCH 3: training on 253115 raw words (115787 effective words) took 0.9s, 130589 effective words/s
# INFO - 01:23:05: EPOCH 4 - PROGRESS: at 94.39% examples, 107842 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:05: EPOCH 4: training on 253115 raw words (115942 effective words) took 1.1s, 108897 effective words/s
# INFO - 01:23:05: Word2Vec lifecycle event {'msg': 'training on 1265575 raw words (579575 effective words) took 4.6s, 124743 effective words/s', 'datetime': '2023-11-13T01:23:05.713617', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# INFO - 01:23:05: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=9195, vector_size=100, alpha=0.03>', 'datetime': '2023-11-13T01:23:05.713617', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}

# %% [markdown]
# 2) Before training, Word2Vec requires us to build the vocabulary table by filtering out the unique words and doing some basic counts on them.
# Use the `build_vocab` function to process the data. If you look at the logs you can see the effect of `min_count` and `sample` on the word corpus.

# %%
# Build the vocabulary table by processing the data (note: this step doesn't train the model yet)
w2v.build_vocab(new_lines, min_count=2, sample=6e-5)
# Out:
# INFO - 01:23:18: collecting all words and their counts
# INFO - 01:23:18: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 01:23:18: PROGRESS: at sentence #10000, processed 80047 words, keeping 9447 word types
# INFO - 01:23:18: PROGRESS: at sentence #20000, processed 162752 words, keeping 13041 word types
# INFO - 01:23:18: PROGRESS: at sentence #30000, processed 243864 words, keeping 16222 word types
# INFO - 01:23:18: collected 16555 word types from a corpus of 253115 raw words and 31213 sentences
# INFO - 01:23:18: Creating a fresh vocabulary
# INFO - 01:23:18: Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 9195 unique words (55.54% of original 16555, drops 7360)', 'datetime': '2023-11-13T01:23:18.213717', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# INFO - 01:23:18: Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 245755 word corpus (97.09% of original 253115, drops 7360)', 'datetime': '2023-11-13T01:23:18.214716', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# INFO - 01:23:18: deleting the raw counts dictionary of 16555 items
# INFO - 01:23:18: sample=6e-05 downsamples 976 most-common words
# INFO - 01:23:18: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 115801.2393707509 word corpus (47.1%% of prior 245755)', 'datetime': '2023-11-13T01:23:18.272913', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# WARNING - 01:23:18: sorting after vectors have been allocated is expensive & error-prone
# INFO - 01:23:18: estimated required memory for 9195 words and 100 dimensions: 11953500 bytes
# INFO - 01:23:18: resetting layer weights
# INFO - 01:23:18: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-13T01:23:18.342289', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}

# %% [markdown]
# 3) Finally, we  train the model. Train the model for 100 epochs. This will take a while. As we do not plan to train the model any further, we call `init_sims()`, which will make the model much more memory-efficient by precomputing L2-norms of word weight vectors for further analysis.

# %%
# Train the Word2Vec model for 100 epochs
w2v.train(new_lines, total_examples=w2v.corpus_count, epochs=100)

# Make the model more memory-efficient by precomputing L2-norms
w2v.init_sims(replace=True)
# Out:
# WARNING - 01:23:21: Effective 'alpha' higher than previous training cycles
# INFO - 01:23:21: Word2Vec lifecycle event {'msg': 'training model with 1 workers on 9195 vocabulary and 100 features, using sg=1 hs=0 sample=6e-05 negative=20 window=3 shrink_windows=True', 'datetime': '2023-11-13T01:23:21.714978', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# INFO - 01:23:22: EPOCH 0 - PROGRESS: at 100.00% examples, 115391 words/s, in_qsize 0, out_qsize 1
# INFO - 01:23:22: EPOCH 0: training on 253115 raw words (115831 effective words) took 1.0s, 115243 effective words/s
# INFO - 01:23:23: EPOCH 1 - PROGRESS: at 94.39% examples, 108055 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:23: EPOCH 1: training on 253115 raw words (115818 effective words) took 1.1s, 108325 effective words/s
# INFO - 01:23:24: EPOCH 2 - PROGRESS: at 94.39% examples, 104222 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:24: EPOCH 2: training on 253115 raw words (116031 effective words) took 1.1s, 104492 effective words/s
# INFO - 01:23:25: EPOCH 3 - PROGRESS: at 82.12% examples, 92778 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:26: EPOCH 3: training on 253115 raw words (115858 effective words) took 1.2s, 92760 effective words/s
# INFO - 01:23:27: EPOCH 4 - PROGRESS: at 98.59% examples, 113660 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:27: EPOCH 4: training on 253115 raw words (115589 effective words) took 1.0s, 113623 effective words/s
# INFO - 01:23:28: EPOCH 5 - PROGRESS: at 98.59% examples, 109783 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:28: EPOCH 5: training on 253115 raw words (115949 effective words) took 1.1s, 109267 effective words/s
# INFO - 01:23:29: EPOCH 6 - PROGRESS: at 98.59% examples, 114142 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:29: EPOCH 6: training on 253115 raw words (115780 effective words) took 1.0s, 114494 effective words/s
# INFO - 01:23:30: EPOCH 7 - PROGRESS: at 90.16% examples, 104074 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:30: EPOCH 7: training on 253115 raw words (115793 effective words) took 1.1s, 104630 effective words/s
# INFO - 01:23:31: EPOCH 8 - PROGRESS: at 90.16% examples, 100321 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:31: EPOCH 8: training on 253115 raw words (115694 effective words) took 1.1s, 102791 effective words/s
# INFO - 01:23:32: EPOCH 9 - PROGRESS: at 94.39% examples, 108770 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:32: EPOCH 9: training on 253115 raw words (115694 effective words) took 1.1s, 110093 effective words/s
# INFO - 01:23:33: EPOCH 10 - PROGRESS: at 98.59% examples, 112845 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:33: EPOCH 10: training on 253115 raw words (115952 effective words) took 1.0s, 113182 effective words/s
# INFO - 01:23:34: EPOCH 11 - PROGRESS: at 98.59% examples, 110664 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:34: EPOCH 11: training on 253115 raw words (115857 effective words) took 1.0s, 111061 effective words/s
# INFO - 01:23:35: EPOCH 12 - PROGRESS: at 94.39% examples, 107620 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:35: EPOCH 12: training on 253115 raw words (115923 effective words) took 1.1s, 107553 effective words/s
# INFO - 01:23:36: EPOCH 13: training on 253115 raw words (115816 effective words) took 0.9s, 128302 effective words/s
# INFO - 01:23:37: EPOCH 14: training on 253115 raw words (115676 effective words) took 0.9s, 124328 effective words/s
# INFO - 01:23:38: EPOCH 15: training on 253115 raw words (115692 effective words) took 0.8s, 140139 effective words/s
# INFO - 01:23:39: EPOCH 16: training on 253115 raw words (115663 effective words) took 0.9s, 129841 effective words/s
# INFO - 01:23:40: EPOCH 17: training on 253115 raw words (115874 effective words) took 1.0s, 121745 effective words/s
# INFO - 01:23:41: EPOCH 18: training on 253115 raw words (115280 effective words) took 0.9s, 127358 effective words/s
# INFO - 01:23:42: EPOCH 19: training on 253115 raw words (115635 effective words) took 1.0s, 116477 effective words/s
# INFO - 01:23:43: EPOCH 20: training on 253115 raw words (115753 effective words) took 0.9s, 127789 effective words/s
# INFO - 01:23:44: EPOCH 21: training on 253115 raw words (115754 effective words) took 1.0s, 119192 effective words/s
# INFO - 01:23:45: EPOCH 22: training on 253115 raw words (116082 effective words) took 0.9s, 124065 effective words/s
# INFO - 01:23:46: EPOCH 23: training on 253115 raw words (115773 effective words) took 1.0s, 120076 effective words/s
# INFO - 01:23:46: EPOCH 24: training on 253115 raw words (116042 effective words) took 0.9s, 124345 effective words/s
# INFO - 01:23:47: EPOCH 25: training on 253115 raw words (115541 effective words) took 0.9s, 132863 effective words/s
# INFO - 01:23:48: EPOCH 26: training on 253115 raw words (115746 effective words) took 1.0s, 117516 effective words/s
# INFO - 01:23:49: EPOCH 27: training on 253115 raw words (115739 effective words) took 0.9s, 122461 effective words/s
# INFO - 01:23:50: EPOCH 28: training on 253115 raw words (115894 effective words) took 0.9s, 134467 effective words/s
# INFO - 01:23:51: EPOCH 29: training on 253115 raw words (115680 effective words) took 0.8s, 137516 effective words/s
# INFO - 01:23:52: EPOCH 30 - PROGRESS: at 94.39% examples, 108560 words/s, in_qsize 2, out_qsize 0
# INFO - 01:23:52: EPOCH 30: training on 253115 raw words (115739 effective words) took 1.1s, 109740 effective words/s
# INFO - 01:23:53: EPOCH 31 - PROGRESS: at 94.39% examples, 107918 words/s, in_qsize 1, out_qsize 0
# INFO - 01:23:53: EPOCH 31: training on 253115 raw words (115983 effective words) took 1.1s, 107952 effective words/s
# INFO - 01:23:54: EPOCH 32: training on 253115 raw words (115703 effective words) took 0.9s, 130622 effective words/s
# INFO - 01:23:55: EPOCH 33: training on 253115 raw words (116329 effective words) took 1.0s, 121416 effective words/s
# INFO - 01:23:56: EPOCH 34: training on 253115 raw words (115787 effective words) took 1.0s, 118159 effective words/s
# INFO - 01:23:57: EPOCH 35: training on 253115 raw words (115868 effective words) took 0.9s, 128582 effective words/s
# INFO - 01:23:58: EPOCH 36: training on 253115 raw words (115955 effective words) took 0.9s, 129997 effective words/s
# INFO - 01:23:59: EPOCH 37: training on 253115 raw words (115813 effective words) took 0.9s, 127388 effective words/s
# INFO - 01:24:00: EPOCH 38: training on 253115 raw words (115932 effective words) took 0.9s, 130615 effective words/s
# INFO - 01:24:00: EPOCH 39: training on 253115 raw words (115900 effective words) took 0.9s, 133325 effective words/s
# INFO - 01:24:01: EPOCH 40: training on 253115 raw words (115736 effective words) took 0.9s, 129842 effective words/s
# INFO - 01:24:02: EPOCH 41: training on 253115 raw words (115818 effective words) took 0.8s, 138265 effective words/s
# INFO - 01:24:03: EPOCH 42: training on 253115 raw words (115623 effective words) took 0.9s, 131668 effective words/s
# INFO - 01:24:04: EPOCH 43: training on 253115 raw words (115937 effective words) took 1.0s, 119952 effective words/s
# INFO - 01:24:05: EPOCH 44: training on 253115 raw words (116124 effective words) took 0.9s, 131306 effective words/s
# INFO - 01:24:06: EPOCH 45: training on 253115 raw words (115820 effective words) took 1.0s, 118587 effective words/s
# INFO - 01:24:07: EPOCH 46: training on 253115 raw words (115836 effective words) took 0.8s, 138524 effective words/s
# INFO - 01:24:08: EPOCH 47: training on 253115 raw words (115773 effective words) took 1.0s, 120104 effective words/s
# INFO - 01:24:09: EPOCH 48: training on 253115 raw words (115527 effective words) took 0.8s, 137269 effective words/s
# INFO - 01:24:10: EPOCH 49: training on 253115 raw words (115909 effective words) took 0.9s, 135603 effective words/s
# INFO - 01:24:10: EPOCH 50: training on 253115 raw words (115654 effective words) took 0.9s, 127760 effective words/s
# INFO - 01:24:11: EPOCH 51: training on 253115 raw words (116019 effective words) took 0.9s, 130726 effective words/s
# INFO - 01:24:12: EPOCH 52: training on 253115 raw words (115700 effective words) took 0.9s, 130418 effective words/s
# INFO - 01:24:13: EPOCH 53: training on 253115 raw words (115893 effective words) took 0.9s, 126280 effective words/s
# INFO - 01:24:14: EPOCH 54 - PROGRESS: at 98.59% examples, 114460 words/s, in_qsize 1, out_qsize 0
# INFO - 01:24:14: EPOCH 54: training on 253115 raw words (115967 effective words) took 1.0s, 114975 effective words/s
# INFO - 01:24:15: EPOCH 55: training on 253115 raw words (115522 effective words) took 0.9s, 124559 effective words/s
# INFO - 01:24:16: EPOCH 56: training on 253115 raw words (115701 effective words) took 0.9s, 130659 effective words/s
# INFO - 01:24:17: EPOCH 57: training on 253115 raw words (115868 effective words) took 0.9s, 125102 effective words/s
# INFO - 01:24:18: EPOCH 58: training on 253115 raw words (115621 effective words) took 0.9s, 133126 effective words/s
# INFO - 01:24:19: EPOCH 59: training on 253115 raw words (115559 effective words) took 0.8s, 138869 effective words/s
# INFO - 01:24:19: EPOCH 60: training on 253115 raw words (115648 effective words) took 0.8s, 136298 effective words/s
# INFO - 01:24:20: EPOCH 61: training on 253115 raw words (115961 effective words) took 1.0s, 120230 effective words/s
# INFO - 01:24:21: EPOCH 62: training on 253115 raw words (115972 effective words) took 1.0s, 119648 effective words/s
# INFO - 01:24:22: EPOCH 63 - PROGRESS: at 94.39% examples, 106121 words/s, in_qsize 2, out_qsize 0
# INFO - 01:24:23: EPOCH 63: training on 253115 raw words (115955 effective words) took 1.1s, 107383 effective words/s
# INFO - 01:24:24: EPOCH 64 - PROGRESS: at 100.00% examples, 115083 words/s, in_qsize 0, out_qsize 1
# INFO - 01:24:24: EPOCH 64: training on 253115 raw words (115554 effective words) took 1.0s, 114956 effective words/s
# INFO - 01:24:25: EPOCH 65 - PROGRESS: at 94.39% examples, 108577 words/s, in_qsize 2, out_qsize 0
# INFO - 01:24:25: EPOCH 65: training on 253115 raw words (115667 effective words) took 1.0s, 110759 effective words/s
# INFO - 01:24:26: EPOCH 66: training on 253115 raw words (115712 effective words) took 0.9s, 124653 effective words/s
# INFO - 01:24:26: EPOCH 67: training on 253115 raw words (115566 effective words) took 0.9s, 131451 effective words/s
# INFO - 01:24:27: EPOCH 68: training on 253115 raw words (116205 effective words) took 0.8s, 146517 effective words/s
# INFO - 01:24:28: EPOCH 69 - PROGRESS: at 98.59% examples, 109644 words/s, in_qsize 1, out_qsize 0
# INFO - 01:24:28: EPOCH 69: training on 253115 raw words (115575 effective words) took 1.0s, 110105 effective words/s
# INFO - 01:24:29: EPOCH 70: training on 253115 raw words (116016 effective words) took 1.0s, 121952 effective words/s
# INFO - 01:24:30: EPOCH 71: training on 253115 raw words (115813 effective words) took 0.9s, 132765 effective words/s
# INFO - 01:24:31: EPOCH 72: training on 253115 raw words (116069 effective words) took 0.9s, 126053 effective words/s
# INFO - 01:24:32: EPOCH 73: training on 253115 raw words (115552 effective words) took 0.9s, 125264 effective words/s
# INFO - 01:24:33: EPOCH 74: training on 253115 raw words (115583 effective words) took 0.9s, 123422 effective words/s
# INFO - 01:24:34: EPOCH 75: training on 253115 raw words (115790 effective words) took 0.7s, 155053 effective words/s
# INFO - 01:24:34: EPOCH 76: training on 253115 raw words (115986 effective words) took 0.8s, 139415 effective words/s
# INFO - 01:24:35: EPOCH 77: training on 253115 raw words (115722 effective words) took 0.9s, 135071 effective words/s
# INFO - 01:24:36: EPOCH 78: training on 253115 raw words (116035 effective words) took 0.9s, 125568 effective words/s
# INFO - 01:24:37: EPOCH 79: training on 253115 raw words (115624 effective words) took 0.9s, 126764 effective words/s
# INFO - 01:24:38: EPOCH 80: training on 253115 raw words (115715 effective words) took 0.8s, 145920 effective words/s
# INFO - 01:24:39: EPOCH 81: training on 253115 raw words (115833 effective words) took 0.9s, 129448 effective words/s
# INFO - 01:24:40: EPOCH 82: training on 253115 raw words (116005 effective words) took 0.9s, 134977 effective words/s
# INFO - 01:24:41: EPOCH 83: training on 253115 raw words (115915 effective words) took 0.8s, 143211 effective words/s
# INFO - 01:24:42: EPOCH 84: training on 253115 raw words (115829 effective words) took 1.0s, 118093 effective words/s
# INFO - 01:24:42: EPOCH 85: training on 253115 raw words (115682 effective words) took 0.8s, 142787 effective words/s
# INFO - 01:24:43: EPOCH 86: training on 253115 raw words (115604 effective words) took 0.8s, 142363 effective words/s
# INFO - 01:24:44: EPOCH 87: training on 253115 raw words (115718 effective words) took 0.8s, 141109 effective words/s
# INFO - 01:24:45: EPOCH 88: training on 253115 raw words (115729 effective words) took 0.9s, 132009 effective words/s
# INFO - 01:24:46: EPOCH 89: training on 253115 raw words (115648 effective words) took 0.9s, 132328 effective words/s
# INFO - 01:24:47: EPOCH 90: training on 253115 raw words (115986 effective words) took 1.0s, 117202 effective words/s
# INFO - 01:24:48: EPOCH 91 - PROGRESS: at 94.39% examples, 108973 words/s, in_qsize 2, out_qsize 0
# INFO - 01:24:48: EPOCH 91: training on 253115 raw words (115741 effective words) took 1.0s, 111585 effective words/s
# INFO - 01:24:49: EPOCH 92: training on 253115 raw words (115838 effective words) took 0.9s, 134470 effective words/s
# INFO - 01:24:50: EPOCH 93: training on 253115 raw words (116180 effective words) took 0.9s, 127656 effective words/s
# INFO - 01:24:51: EPOCH 94: training on 253115 raw words (116295 effective words) took 1.0s, 118055 effective words/s
# INFO - 01:24:52: EPOCH 95: training on 253115 raw words (115971 effective words) took 0.9s, 129305 effective words/s
# INFO - 01:24:52: EPOCH 96: training on 253115 raw words (115792 effective words) took 0.8s, 138239 effective words/s
# INFO - 01:24:53: EPOCH 97: training on 253115 raw words (115925 effective words) took 1.0s, 121089 effective words/s
# INFO - 01:24:54: EPOCH 98: training on 253115 raw words (115732 effective words) took 0.8s, 137234 effective words/s
# INFO - 01:24:55: EPOCH 99: training on 253115 raw words (115850 effective words) took 0.9s, 132858 effective words/s
# INFO - 01:24:55: Word2Vec lifecycle event {'msg': 'training on 25311500 raw words (11581018 effective words) took 93.9s, 123389 effective words/s', 'datetime': '2023-11-13T01:24:55.572941', 'gensim': '4.3.2', 'python': '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# C:\Users\ozgeb\AppData\Local\Temp\ipykernel_10744\513967249.py:5: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v.init_sims(replace=True)
# WARNING - 01:24:55: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %% [markdown]
# ### Subtask 3: Exploring the Model

# %% [markdown]
# As mentioned in the lecture, word embeddings are suited for similarity and analogy tasks. Let's explore some of that with our dataset:
#
# We look for the most similar words to the name of the famous coffee shop where most of the episodes took place, namely `central_perk` and also one of the characters `joey`. If you have followed the exercise correctly until now, you should see that words like `laying` are similar to `central_perk` and the other main characters are also considered similar to `joey`.

# %%
###your code###
# Find the most similar words to "central_perk"
similar_to_central_perk = w2v.wv.most_similar("central_perk", topn=10)
print("Words similar to 'central_perk':")
for word, score in similar_to_central_perk:
    print(f"{word}: {score}")
# Out:
# Words similar to 'central_perk':
# conan: 0.5657062530517578
# back: 0.5628068447113037
# to: 0.5581588745117188
# aaah: 0.5395253896713257
# hippity: 0.5235718488693237
# laying: 0.49164921045303345
# mitzi: 0.48723304271698
# rehearsing: 0.48340925574302673
# crossword: 0.48173514008522034
# russ: 0.47946953773498535

# %%
###your code###
# Find the most similar words to "joey"
similar_to_joey = w2v.wv.most_similar("joey", topn=10)
print("\nWords similar to 'joey':")
for word, score in similar_to_joey:
    print(f"{word}: {score}")
# Out:
# Words similar to 'joey':
# chandler: 0.8833669424057007
# ross: 0.8736824989318848
# monica: 0.8356947302818298
# right: 0.8232203722000122
# oh: 0.8205116987228394
# rachel: 0.8200818300247192
# phoebe: 0.7992911338806152
# looks: 0.7982349991798401
# look: 0.7931801080703735
# good: 0.7848427295684814

# %% [markdown]
# Look at the similarity of `green` to `rachel` (her lastname) and `ross`  and `spaceship` (urelated). The first one should have a high and the second a low score. Finally, look at the similarity of `smelly_cat` ( a song from pheobe) and `song` the similarity should be high.

# %%
###your code###
similarity_green_rachel = w2v.wv.similarity("green", "rachel")
print("Similarity between 'green' and 'rachel':", similarity_green_rachel)
# Out:
# Similarity between 'green' and 'rachel': 0.2968682

# %%
###your code###
# Calculate similarity between "green" and "ross"
similarity_green_ross = w2v.wv.similarity("green", "ross")
print("Similarity between 'green' and 'ross':", similarity_green_ross)

# Calculate similarity between "green" and "spaceship"
similarity_green_spaceship = w2v.wv.similarity("green", "spaceship")
print("Similarity between 'green' and 'spaceship':", similarity_green_spaceship)
# Out:
# Similarity between 'green' and 'ross': 0.2563247
# Similarity between 'green' and 'spaceship': 0.23675239

# %%
###your code###
# Calculate similarity between "green" and "spaceship"
similarity_green_spaceship = w2v.wv.similarity("ross", "spaceship")
print("Similarity between 'ross' and 'spaceship':", similarity_green_spaceship)

# Calculate similarity between "smelly_cat" and "song"
similarity_smelly_cat_song = w2v.wv.similarity("smelly_cat", "song")
print("Similarity between 'smelly_cat' and 'song':", similarity_smelly_cat_song)
# Out:
# Similarity between 'ross' and 'spaceship': 0.25830737
# Similarity between 'smelly_cat' and 'song': 0.45493168

# %% [markdown]
# We can also ask our model to give us the word that does not belong to a list of words. Let's see from the list of all 5 characters which one is the most dissimilar?

# %%
character_names= ['joey', 'rachel', 'phoebe','monica','chandler']

# %%
odd_one_out = w2v.wv.doesnt_match(character_names)
print("The character name that does not belong:", odd_one_out)
# Out:
# The character name that does not belong: joey

# %% [markdown]
# Based on the analogies, which word is to `monica` as `man` is to `women`? (print the top 3 words); you should get `chandler`among the answers.

# %%
analogy_result = w2v.wv.most_similar(positive=["monica", "woman"], negative=["man"], topn=3)
print("Words similar to 'monica' in the context of 'woman' like 'man':")
for word, score in analogy_result:
    print(f"{word}: {score}")
# Out:
# Words similar to 'monica' in the context of 'woman' like 'man':
# rachel: 0.7193353772163391
# ross: 0.7127968668937683
# chandler: 0.684895396232605

# %% [markdown]
# Finally, lets use [t-SNE](https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf) to look at the distribution of our embeddings in the vector space for the character `joey`. Follow the instructions and fill in the blank in the `tsneplot` function.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sys
from sklearn.manifold import TSNE

# %%
def tsneplot(model, word):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction for the top 10 most similar and dissimilar words
    """
    embs = np.empty((0, 100), dtype='f')# to save all the embeddings
    word_labels = [word]
    color_list  = ['green']

    # adds the vector of the query word
    embs = np.append(embs, model.wv.__getitem__([word]), axis=0)

    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    all_sims = model.wv.most_similar([word], topn=sys.maxsize)
    far_words = list(reversed(all_sims[-10:]))

    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        embs = np.append(embs, wrd_vector, axis=0)

    # adds the vector for each of the furthest words to the array
    for wrd_score in far_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('red')
        embs = np.append(embs, wrd_vector, axis=0)

    np.set_printoptions(suppress=True)
    Y = TSNE(n_components=2, random_state=110, perplexity=15).fit_transform(embs)

    # sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})

    fig, _ = plt.subplots()
    fig.set_size_inches(10, 10)

    # basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )

    # adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)


    plt.xlim(Y[:, 0].min()-1, Y[:, 0].max()+1)
    plt.ylim(Y[:, 1].min()-1, Y[:, 1].max()+1)

    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
tsneplot(w2v, 'joey')

# %% [markdown]
# ## **Task 2: Questions on the Conceptual Level (non-programming) (Grade (2 + 1 + 1 + 4) = 8)**

# %% [markdown]
# Please answer the following questions in the notebook cells using markdown. Be precise and short.

# %% [markdown]
# ### Subtask 1: For gradient descent, what advantage has a decaying learning rate?

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# ### Subtask 2: Why is it easier to maximize the log likelihood instead of the "normal" likelihood?

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# ### Subtask 3: Name one advantage that fastText has over Word2Vec?

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# ### Subtask 4: Compute the partial derivate of softmax loss for word2vec with
#
# ---
#
# respect to the center word vector.
# $$ \frac{\partial J}{\partial v_c} =\frac{\partial}{\partial v_c}\left[ -log \left( \frac{exp(u^T_o v_c)}{\Sigma_{w \in Vocab} exp(u^T_o v_c)} \right)\right] $$
# use $U$ to denote the matrix of all embeddings and $y$ for a one-hot vector with a 1 for the true outside word $o$, and $\hat{y}$ for the predicted distribution $P(w|c)$.

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# ## **Task 3: Auto-Complete Feature (Grade (2 + 6 + 4) = 12)**
#
# Let's get even more practical! In this problem set, you will build your own auto-completion system that you see every day while using search engines.
#
# [google]: https://www.thedad.com/wp-content/uploads/2018/05/screen-shot-2018-05-12-at-2-01-56-pm.png "google auto complete"
#
# ![google]
# By the end of this assignment, you will develop a simple prototype of such a system using n-gram language model. At the heart of the system is a language model that assigns the probability to a sequence of words. We take advantage of this probability calculation to predict the next word.
#
# The problem set contains 3 main parts:
#
# 1. Load and preprocess data (tokenize and split into train and test)
# 2. Develop n-gram based language model by estimating the conditional probability of the next word.
# 3. Evaluate the model by computing the perplexity score.

# %% [markdown]
# ### Subtask 1: Load and Preprocess Data
# We use a subset of English tweets to train our model. Run the cell below to load the data and observe a few lines of it. Notice that tweets are saved in a text file, where the individual tweets are separated by `\n`

# %%
import spacy
nlp = spacy.load("en_core_web_sm", disable=["tagger", "parser","ner"])


with open("./twitter.txt", "r") as f:
    data = f.read()
print("First 500 characters of the data:")
display(data[0:500])
print("-------")

# %% [markdown]
# Now we need to separate the tweets and split them into train and test set. Apply the following pre-processing steps:
#
# 1. Split data into sentences using "\n" as the delimiter and remove the leading and trailing spaces (drop empty sentences)
# 2. Tokenize the sentences into words using SpaCy and lowercase them. (notice that we do not remove stop words or punctuations.)
# 3. Divide the sentences into 80 percent training and 20 percent test set. No validation set is required. Although in a real-world application it is best to set aside part of the data for hyperparameter tuning.
# 4. To limit the vocabulary and remove potential spelling mistakes, make a vocabulary of the words that appear at least 2 times. The rest of the words will be replaced by the `<unk>` symbol. This is a crucial step since if your model encounters a word that it never saw during training, it won't have an input word that helps determining the next word for suggestion. We use the `<unk>` word for **out of Vocabulary (OOV)** words. Keep in mind that we built the vocabulary on the training data only.

# %%
sentences = #split
sentences = #remove spaces and drop empty sentences

# %%
tokenized_corpus = []# list of list of the tokens in a sentence
##Your Code###

# %%
from random import Random
Random(4).shuffle(tokenized_corpus)

train = ##Your Code###
test = ##Your Code###

# %%
from collections import Counter
flatten_corpus = ### Flatten the train corpus ###
word_counts = ### count the number of each token ###
vocab = []

### keep only the ones with frequency bigger than 2 ###
print(len(vocab)) ### should be 14861 ###
train_replaced = []
test_replaced = []
for sentence in train:
    ### adjust the sentence to contain the word in the vocabulary and <unk> for the rest ####
for sentence in test:

# %% [markdown]
# ### Subtask 2: N-gram Based Language Model:
# In this section, you will develop an n-grams language model [**1. Large Language Models (LLMs), slide 1-24**]. We assume that the probability of the next word depends only on the previous n-gram or previous n words. We compute this probability by counting the occurrences in the corpus.
# The conditional probability for the word at position 't' in the sentence, given that the words preceding it are $w_{t-1}, w_{t-2} \cdots w_{t-n}$ can be estimated as follows:
#
# $$ \hat{P}(w_t | w_{t-1}\dots w_{t-n}) = \frac{C(w_{t-1}\dots w_{t-n}, w_t)}{C(w_{t-1}\dots w_{t-n})}  $$
#
# The numerator is the number of times word '$w_t$' appears after the n-gram, and the denominator is the number of times the n-gram occurs in the corpus, where $C(\cdots)$ is a count function. Later, we add k-smoothing to avoid errors when any counts are zero.

# %% [markdown]
# To tackle the problem of probability estimation we divide the problem into 3 parts. In the following you will:
# 1. Implement a function that computes the counts of n-grams for an arbitrary number n.
# 2. Estimate the probability of a word given the prior n-words using the n-gram counts.
# 3. Calculate probabilities for all possible words.
# The steps are detailed below.

# %% [markdown]
# Let's start by implementing a function that computes the counts of n-grams for an arbitrary number n.
# - Prepend necessary starting markers `<s>` to indicate the beginning of the sentence. In the case of a bi-gram model, you need to prepend two start tokens `<s><s>` to be able to predict the first word. "hello world"-> "`<s><s>`hello world".
# - Append an end token `<e>` so that the model can predict when to finish a sentence.
# - Create a dictionary to store all the n_gram counts.

# %%
def n_grams_counts(corpus, n):
    """
    Count all n-grams in the corpus given the parameter n

    data: List of lists of words (your tokenized corpus)
    n: n in the n-gram

    Returns: A dictionary that maps a tuple of n words to its frequency
    """
    start_token='<s>'
    end_token = '<e>'
    n_grams = defaultdict(int)
    for sentence in corpus:
        sentence = ### add start and end token ###
        # convert list to tuple so it can be used a the key in the dictionary
        sentence = tuple(sentence)

        ###iterate over the n-grams in the sentence, you can use the range() function, and increament the counts in the
        ## n_grams dictionary, where the key is the n_gram and the value is count
    return n_grams

# %% [markdown]
# The next step is to estimate the probability of a word given the prior n words using the n-gram counts, based on the formula given at the beginning of this task. To deal with the problem of zero division we add k-smoothing. K-smoothing adds a positive constant $k$ to each numerator and $k \times |vocabulary size|$ in the denominator. Below we will define a function that takes in a dictionary `n_gram_cnt`, where the key is the n-gram, and the value is the count of that n-gram, plus a dictionary for `plus_current_gram_cnt`, which you'll use to find the count for the previous n-gram plus the current word. Notice that these dictionaries are computed using the previous function `n_grams_counts`.

# %%
def probability(word, prev_n_gram,
                         n_gram_cnts, plus_current_gram_cnts, vocab_size):
    """
    Estimate the probabilities of the next word using the n-gram counts with k-smoothing
    word: next word
    prev_n_gram: previous n gram
    n_gram_cnts: dictionary of counts of n-grams
    plus_current_gram_cnts: dictionary of counts of (n+1)-grams -> current word+ n-gram = (n+1)-gram
    vocab_size: number of words in the vocabulary

    Returns: A probability
    """
    k=1.0
    prev_n_gram = tuple(prev_n_gram)

    prev_n_gram_cnt =  # get the previous n-gram count from the dictionary
    denominator = # denominator with the previous n-gram count and k-smoothing
    plus_current_gram =  # add the current word to the n-gram
    plus_current_gram_cnts =  # get the current n-gram count using the dictionary
    numerator = #calculate the numerator with k-smoothing
    prob =

    return prob

# %% [markdown]
# Let's use the functions we have defined to calculate probabilities for all possible words.

# %%
def probabilities(prev_n_gram, n_gram_cnts, plus_current_gram_cnts, vocab):
    """
    Estimate the probabilities for all the words in the vocabulary given the previous n-gram
    prev_n_gram: previous n-gram
    n_gram_cnts: dictionary of counts of n-grams
    plus_current_gram_cntsplus_current_gram_cnt: dictionary of counts of (n+1)-grams -> current word+ n-gram = (n+1)-gram
    vocab: List of words

    Returns: A dictionary mapping from next words to the probability.
    """
    prev_n_gram = tuple(prev_n_gram)

    vocab =  # add <e> <unk> to the vocabulary
    vocabulary_size = #compute the size

    probabilities = {}
    for word in vocab:
        ### compute the probability
    return probabilities

# %%
# Predict the probability of all possible words after the unigram "the"
sentences = [['the', 'moon', 'and', 'stars', 'are','shining','bright'],
             ['the', 'moon', 'is', 'shinnig','tonight'],
             ['mars','and' ,'moon', 'are', 'plants'],
             ['the' ,'moon', 'is','a', 'plant']]
unique_words = list(set(sentences[0] + sentences[1] + sentences[2]+ sentences[3]))
unigram_counts = n_grams_counts(sentences, 1)
bigram_counts = n_grams_counts(sentences, 2)
print("The word 'moon' should have the highest probability, if it is not the case, re-visit your previous functions.")
probabilities(["the"], unigram_counts, bigram_counts, unique_words)

# %% [markdown]
# ### Subtask 3: Evaluation

# %% [markdown]
# In this part, we use the perplexity score to evaluate your model on the test set. The perplexity score of the test set on an n-gram model is defined as follows:
#
# $$ PP(W) =\sqrt[N]{ \prod_{t=n}^{N-1} \frac{1}{P(w_t | w_{t-n} \cdots w_{t-1})} } $$
# - where $N$ is the length of the sentence. ($N-1$ is used because in the code we start from the index 0).
# - $n$ is the number of words in the n-gram.
# - $W$ is the n-gram
#
# Notice that we have already computed this probability.
#
# The higher the probabilities are, the lower the perplexity will be.

# %%
def perplexity(sentence, n_gram_cnts, plus_current_gram_cnts, vocab_size, k=1.0):
    """
    Calculate perplexity for a list of sentences
    sentence: List of strings
    n_gram_cnts: dictionary of counts of n-grams
    plus_current_gram_cnts: dictionary of counts of (n+1)-grams -> current word+ n-gram = (n+1)-gram
    vocab_size: number of unique words in the vocabulary
    k: positive smoothing constant

    Returns: Perplexity score for a single sentence
    """

    n =  # get the number 'n' in  n-gram  from n_gram_cnts

    sentence =  # prepend <s> and append <e>
    sentence = tuple(sentence)
    N =# length of sentence


    product_pi = 1.0

    ### Compute the product of probabilities ###

    for t in range(n, N):
        n_gram =# get the n-gram before the predicted word (n-gram before t )
        word =  # get the word to be predicted (position t)
        prob = probability(....) # your code instead of ....
        product_pi *= # Update the product of the probabilities

    perplexity = product_pi**(1/float(N)) # Take the Nth root of the product
    return perplexity

# %% [markdown]
# Use `perplexity` function to find the perplexity of a bi-gram model on the first training sample and on the first test sample (first element of the set).

# %%
bigram_counts = ### your code ###
trigram_counts = ### your code ###

perplexity_train = perplexity(train_replaced[0],bigram_counts, trigram_counts,len(vocab))
print(f"Perplexity for first train sample: {perplexity_train:.4f}")

perplexity_test = perplexity(test_replaced[0],bigram_counts, trigram_counts,len(vocab))
print(f"Perplexity for test sample: {perplexity_test:.4f}")# the perplexity for the train sample should be much lower

# %% [markdown]
# Finally, let's use the model we created to generate an auto-complete system that makes suggestions.

# %%
def suggest_a_word(up_to_here, n_gram_cnts, plus_current_gram_cnts, vocab , start_with=None):
    """
    Get suggestion for the next word
    up_to_here: the sentence so far, must have length > n
    n_gram_cnts: dictionary of counts of n-grams
    plus_current_gram_cnts: dictionary of counts of (n+1)-grams -> current word+ n-gram = (n+1)-gram
    vocab: List of words
    start_with: If not None, specifies the first few letters of the next word

    Returns: (most likely next word,  probability)
    """
    n = len(list(n_gram_cnts.keys())[0]) # get the number 'n' in  n-gram  from n_gram_cnts
    previous_n_gram = previous_tokens[-n:] # get the last 'n' words as the previous n-gram from the input sentence


    probabs = # Estimate the probabilities for each word in the vocabulary

    probabs =
    ### sort the probability for higher to lower and return the highest probability word,probability tuple
    #if start_with is specified then return the highest probability word that starts with that specific character

# %% [markdown]
# Test your model based on the bi-gram model created on the training corpus.

# %%
previous_tokens=['i','like']
start_with='b'
suggestion = suggest_a_word(previous_tokens, bigram_counts,trigram_counts, list(vocab),start_with=start_with)
suggestion

# %%
previous_tokens=['i','like','to']
start_with=None
suggestion = suggest_a_word(previous_tokens, bigram_counts,trigram_counts, list(vocab),start_with=start_with)
suggestion

# %%
previous_tokens=["hello", "my", "name", "is"]
start_with=None
suggestion = suggest_a_word(previous_tokens, bigram_counts,trigram_counts, list(vocab),start_with=start_with)
suggestion

# %%
previous_tokens=["hello", "my", "name", "is"]
start_with='a'
suggestion = suggest_a_word(previous_tokens, bigram_counts,trigram_counts, list(vocab),start_with=start_with)
suggestion

# %% [markdown]
# ## **Task 4: Understanding GloVe (Grade (2 + 4.25 + 4 + 1.75) = 12)**

# %% [markdown]
# In this part, you will implement the [GloVe](https://nlp.stanford.edu/projects/glove/) model and train your own word vectors with gradient
# descent and numpy. GloVe stands for Global Vectors for word representation, which was developed by researchers at Stanford University to generate word embeddings from corpus statistics.
# The statistics of the corpus are represented by a co-occurrence matrix, indicating how often a particular word pair occurs together.
# GloVe is based on ratios of probabilities from this co-occurrence matrix, combining the intuitions of count-based models while also being similar to neural models like word2vec.
# From this matrix, one can compute the co-occurrence probabilities. We motivate this with an example:
#
# $P_{ik} = P(i,j)$ -> co-occurrence probability or joint probability of words $i$ and $k$
#
# $P_{jk}$ ->co-occurrence probability of words $j$ and $k$
#
# $\frac{P_{ik}}{P_{jk}}$-> corelation between $i$ and $j$ with the prob word $k$
#
# This ratio gives us some insight into the co-relation of the probe word $k$ with the words $i$ and $j$.
# An example is shown below for different prob words $k$, where $i$ and $j$ are `ice` and `steam`, respectively.

# %% [markdown]
# ![glove](https://nlp.stanford.edu/projects/glove/images/table.png)

# %% [markdown]
# Image taken from Stanford NLP.

# %% [markdown]
# Compared to the raw probabilities, the ratio of probabilities is better able to distinguish relevant words from irrelevant words. Consider the raw probabilities (the first two rows), the values are close to one another and not indicative of the relationships. However, the ratios have more distinct values.
#
# This ratio can be small, large, or equal to 1 depending on the prob word and their co-relation. In the example above, the ratio between ice and steam for `k=solid` is large and for `k=gas` is small, indicating that `solid` is related to ice but `gas` is irrelevant. On the other hand, `water` is not a discriminating element between them, and therefore the ratio is close to one. The same applies to an irrelevant word like `fashion`.
#
# The GloVe model is built on the idea that the "ratio of conditional probabilities represents the word meanings" and a neural model is trained to estimate this conditional probability.
#
# $F(w_i,w_j,\tilde{w_k})=\frac{P_ik}{P_jk}$ -> the right-hand side is computed from the corpus statistics, $w$ is the word vector and $\tilde{w_k}$ is the context vector
#
# The GloVe model embeds the words in a vector space and claims that the difference between them (distinguishing factor) is hidden in the ratio of probabilities. In vector space, the best way to encode this is by vector differences.
#
# $F((w_i-w_j),\tilde{w_k})=\frac{P_ik}{P_jk}$
#
# At this point, the left-hand side is a vector and the right-hand side is a scalar showing the similarity of i and j with the context word k.
# For both sides to match and to encode the similarity in the vector space, the left-hand side becomes a dot product.
#
# $F((w_i-w_j)^{T}.\tilde{w_k})=\frac{P_ik}{P_jk}=\frac{F(w_i.\tilde{w_k})}{F(w_j.\tilde{w_k})} $
#
# $F(w_i.\tilde{w_k})=\frac{X_{ik}}{X_{i}}$ -> where $X$ is drived from the co-occurrences matrix
#
# To satisfy a symmetrical relationship (a.k.a. relation(a, b) = relation(b, a)), $F$ is chosen to be an exponential function, $F(x)=exp(x)$. As a result:
#
# $w_i.\tilde{w_k} = log(P_{ik} ) = log(X_{ik} ) − log(X_{i})$
#
# $log(X_{i})$ is independent of $k$ and can be absored into a bias term.
#
# $w_i.\tilde{w_k} = log(P_{ik} ) + b_i +\tilde{b_k} = log(X_{ik} )$
#
# After some weighting and alterations the final cost function, based on the weighted least squares regression model is as follows:
#
# $J= \Sigma^{V}_{i,j=1} f(X_{ij})(w_i.w_j+ b_i +b_j)-log(X_{ik})$
#
# For a detailed overview refer to the original paper: https://nlp.stanford.edu/pubs/glove.pdf
# You need to read and understand the GloVe model to solve this exercise.

# %% [markdown]
# ### Subtask 1: Cost function

# %% [markdown]
# Read the paper and describe the following, in your own words:
#
#  1. The intuition behind the weighting schema in the cost function.
#
#  2. How does the objective function of GloVe relate to the objective function of the (word2vec) skip-gram model?

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# <<< your answer >>>

# %% [markdown]
# ### Subtask 2: Build Co-occurence matrix

# %% [markdown]
# We use the same dataset as the first task and use the `quotes` as the corpus to build the co-occurrences matrix. Similar to the first task we use the `phrases` to transform our input and extract the vocabulary.

# %%
import numpy as np
from scipy import sparse
from math import log
from itertools import chain
from collections import Counter
from tqdm import tqdm

# %% [markdown]
# Complete the function to create dictionaries used for mapping ids to words and words to ids, and a dictionary that counts the number of occurrences of each word. The first two dictionaries are used to map indices in vector space to words and back, and the third dictionary contains the counts of the corpus statistics.

# %%
def create_vocab(corpus):
  """
  Build a vocabulary containing the frequencies
  corpus: the list of tokenized lines form the corpus

  Returns  dictionaries `word` -> (index or unique identified), frequency)`
  and `word` -> (index or unique identified)
  and index or unique identified -> `word`
  and length of the vocab
  """

  word_count_dict = {} # word id to the number of time it appears
  id_to_word={} # mapping ids to words
  word_to_id={} # mapping words to ids
  ### you code goes here###


  return word_count_dict,id_to_word,word_to_id, len(word_count_dict)

# %%
word_count_dict, id_to_word,word_to_id, vocab_size=create_vocab(new_lines)

# %% [markdown]
# If you have done the exercise correctly, you have `15333` tokens in the vocabulary, and the number of occurrences for `joey` is `1951` and for `central_perk` is `36`

# %%
print("number of occurrences for joey:",word_count_dict[word_to_id['joey']])
print("number of occurrences for central perk:",word_count_dict[word_to_id['central_perk']])
print("vocab size is:",vocab_size)

# %%
def calculate_weight(cooccurrences, context_word_ids, center_word_id, side):
    """
    Calculate the weight in the co-occurrence matrix based on the distance of a word
    to the center word
    sentence = [I, went, to , the, bank]
    Let center word be "to" and window size =2
    left_context =[I,went]
    right_context = [the,bank]

    Weights:
    1/distance-> `went` and `the` have weight of 1 and `I` and `bank` have weight of 1/2
    """

    if side == "right_context":
        context_word_ids.reverse()

      ## adjust the weight of the matrix to 1/distance between the center word and context word, where center word will act as the row and the context word is the column##

    return cooccurrences

# %% [markdown]
# The weight of first to second element on the example matrix should be `1.0`.

# %%
cooccurrences = sparse.lil_matrix((10, 10),dtype=np.float64)
calculate_weight(cooccurrences, [1,3,5], 0, side="right_context")
print("weight of id=0 to id=1 :",cooccurrences[0,1])

# %% [markdown]
# We build co-occurrence as a sparse matrix to speed up the computation. The original matrix is a square matrix in the size of the vocabulary. However, many words do not co-occur with one another and we do not need to store those elements.

# %%
def build_cooccur(corpus, window_size=3, min_count=5):
    """
    Create a coocurrance matrix given a corpus
    corpus: the list of tokenized lines form the corpus
    window_size: how many words to right and left to consider

    Returns the co-oocurrance sparse matrix
    """
    vocab, id_to_word,word_to_id, vocab_size= create_vocab(corpus)

    #sparse lil_matrix is optimized to operate on matrix which mostly has zeros.
    cooccurrences = sparse.lil_matrix((vocab_size, vocab_size),dtype=np.float64)

    for i, line in enumerate(corpus):

        #Get the ID of words from vocab dictionary
        word_ids = [word_to_id[word] for word in line]

        for i, center_word_id in enumerate(word_ids):

            left_context_word_ids  =#left side context


            right_context_word_ids = #right side context

            ###update the matrix based on the distance weights on both sides###

    # go into the LiL-matrix to quickly iterate through all nonzero cells and filter out the ones with minimum count
    cooccurrences_tuples = []
    for i, (row, data) in enumerate(zip(cooccurrences.rows,cooccurrences.data)):

      ## check if the min_count condition is statisfied and then add the elements as the tuple of (i,j,weight)###
    return cooccurrences_tuples

# %% [markdown]
# Build a matrix with a window_size of 3 words, and the minimum number of times a word has to occur to be part of the matrix is 10.

# %%
matrix=build_cooccur(new_lines, window_size=3, min_count=10)
matrix[103]

# %% [markdown]
# ### Subtask 3: Modelling and Training

# %% [markdown]
# We initialize the weights for the context and center words and learn the vectors through backprop, using the GloVe cost function.
# Make sure you use the correct weighting schema.

# %%
# Random normal weights intialization
np.random.seed(77)# we set a seed to have similar results
def init_weights(vocab_size, hidden):
     #Each word has a center word vector and a context vector.
    W_center = np.random.randn(# initilize the correct size vector
    b_center = # initilize the correct size vector
    W_context = # initilize the correct size vector
    b_context = # initilize the correct size vector
    return W_center, b_center, W_context, b_context

# %% [markdown]
# keep track of `W_center[0,1]` as it should change based on backprop in the next cells.

# %%
W_center, b_center, W_context, b_context=init_weights(100, 32)
print("check the shapes to make sure the matrices have correct sizes:")
print(W_center.shape)
print(b_center.shape)
print(W_context.shape)
print(b_context.shape)
print("Look at the value of this element and how it changes with back prob:")
print(W_center[0,1])

# %% [markdown]
# Write a training script for the GloVe model that goes over the entire co-occurrence matrix given a number of epochs.

# %%
# Back Propagation
def back_prop(W_center, b_center, W_context, b_context, matrix, x_max,  vocab_size, learning_rate,alpha=2):
    """
    W_center, b_center: weight and bias of the center word
    W_context, b_context: weight and bias of the context word
    vocab_size: vocabulary size
    x_max: define our weighting function when computing the cost for two word pairs; see the GloVe paper for more
    details.
    matrix: coocurrance matrix
    alpha: the power of x_max function
    learning_rate: learning rate for gradient descent
    """

    global_cost = 0
    for i, j, cooccurrence in matrix:
            weight = ((cooccurrence/x_max)**alpha if(cooccurrence < x_max) else 1)
            # Compute inner component of cost function  J' = w_i^Tw_j + b_i + b_j - log(X_{ij})

            ##Compute cost J = f(X_{ij}) (J')^2##


            ##Compute gradients for word vectors##

            ##Compute gradients for bias terms##


            ##update the weights##


    return W_center, b_center, W_context, b_context, global_cost

# %% [markdown]
# Based on the random seed, the value of `W_center[0,1]` should have changed due to backpropagation.

# %%
test_matrix=[(0,1,1),(0,2,0.4),(0,3,0.9),(0,4,0.4)]
W_center, b_center, W_context, b_context, global_cost  =back_prop(W_center, b_center, W_context, b_context, test_matrix, x_max=10,  vocab_size=100, learning_rate=0.01)
print("cost:",global_cost)
print("changed value:")
print(W_center[0,1])

# %% [markdown]
# Write a training script for the GloVe model that goes over the entire co-occurrence matrix given a number of epochs.

# %%
def train_GloVe(matrix, vocab_size, epochs = 10, learning_rate = 0.0001, x_max = 10, hidden_dim=100):
    """
    Train the glove model based the co-ocurrance matrix for a number of epochs
    matrix: co-occcurance matrix
    vocab_size: number of words in vocab
    epochs: number of passes through the data
    learning_rate: learning rate for back prop
    x_max: parameter of the weighting function
    hidden_dim: dimension of the vectors
    """
    W_center, b_center, W_context, b_context = init_weights(vocab_size, hidden_dim)
    for i in tqdm(range(epochs)):
        ### perform backprop###
        print(global_cost)
    return W_center, W_context

# %% [markdown]
# Train the model with hidden dimension of `100` and learning rate of `0.001` for a `100` epochs.

# %%
W_center, W_context = ## your code ##

# %% [markdown]
# As you can see by looking at the loss, the model still needs more time to converge to a minimum.
# However, we keep the training short and keeping in mind that the vectors can improve we look at some examples.
# Take the average, transpose, and normalize the matrix.

# %%
from numpy.linalg import norm
# take the average of the learned vector as the final vector
W = np.add(W_center, W_context)/2
W = W.T
W = W/norm(W)

# %%
W.shape

# %% [markdown]
# Lets create a dictionary that points from a word to its vector.

# %%
# Generates word to word embedding dictionary
word_to_vector = {}
for word in word_to_id.keys():
    word_to_vector[word] = W[:, word_to_id[word]]

# %% [markdown]
# ### Subtask 4: Compare to Skip-gram

# %% [markdown]
# Let's compute the similarities for the same words in Task 1 to compare the results with word2vec. This time you need to implement the similarity function, based on the dot product. To get to the topk you need to sort the elements based on their similarity.

# %%
from numpy import dot

def most_similar(word_vector,all_vectors,id_to_word, topk):
    """
    function to find the topk most similar words to a word vector
    word_vector: vector of the search word
    all_vectors: all word vectors
    id_to_word: dictionary from id to words
    topk: number of elements to return
    """
    ### find the topk most similar words to a given word vector ##
    return word

# %%
most_similar(word_to_vector["central_perk"],W,id_to_word,5)

# %%
most_similar(word_to_vector["joey"],W,id_to_word,5)

# %% [markdown]
# Compute the similarity between the `('rachel', 'mrs_green')`, `('smelly_cat', 'song')` and `('ross', 'spaceship')`.

# %%
## your code ##

# %%
## your code ##

# %%
## your code ##

# %% [markdown]
# If you see your results are not as meaningful as the gensim model, do not be discouraged. With better optimization and longer training the results should improve. If you have time play around a bit more with your model and see if you can generate more meaningful vectors.
